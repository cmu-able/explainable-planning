# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 30)

# %%
df_assignments_ctrl = pd.read_csv('../XPlanningEvaluation/resources/mobilerobot/study/prefalign/mturk/assignments/assignments_control_full.csv')
df_assignments_expr = pd.read_csv('../XPlanningEvaluation/resources/mobilerobot/study/prefalign/mturk/assignments/assignments_experimental_full.csv')
df_answers_ctrl = pd.read_csv('../XPlanningEvaluation/resources/mobilerobot/study/prefalign/mturk/assignments/answerKey_control.csv')
df_answers_expr = pd.read_csv('../XPlanningEvaluation/resources/mobilerobot/study/prefalign/mturk/assignments/answerKey_experimental.csv')

# %%
df_assignments_ctrl.head()
# Out:
#    HIT Index                          HIT ID                      HITType ID  \
# 0          0  3BA7SXOG1LPO17RJMOEPLRAB3IOR82  35280GTXAPQ35X4ZWHDC3QI4GWDOVS
# 1          0  3BA7SXOG1LPO17RJMOEPLRAB3IOR82  35280GTXAPQ35X4ZWHDC3QI4GWDOVS
# 2          0  3BA7SXOG1LPO17RJMOEPLRAB3IOR82  35280GTXAPQ35X4ZWHDC3QI4GWDOVS
# 3          0  3BA7SXOG1LPO17RJMOEPLRAB3IOR82  35280GTXAPQ35X4ZWHDC3QI4GWDOVS
# 4          1  3UOMW19E6F518NJY6THRKC1Y1RRC5M  35280GTXAPQ35X4ZWHDC3QI4GWDOVS
#
#                     Assignment ID       Worker ID  Total Time (seconds)  \
# 0  3PWWM24LHVXAK78SX04Q83YSQOR28Y   A7P3R1AIA4TVV                  1106
# 1  3GFK2QRXXCGD95NXDMMUKQ4QS5L5WH  A1SIUJEL2LS8UO                  1164
# 2  35BLDD71I9WY1U7HU0OENSS7MVTVZ6  A272X64FOZFYLB                   722
# 3  3WOKGM4L74F69PSUPUP8M1VD8WUO0O  A1DMXEJGJY02E1                   721
# 4  3P4RDNWND853F9IDD7M9K9ENVWLIJE  A38Z99XF4NDNH0                   471
#
#                question0-ref question0-total-cost question0-answer  \
# 0  question-mission12-agent0                  181              yes
# 1                       null                 null             null
# 2  question-mission12-agent0                  206              yes
# 3  question-mission12-agent0                189.8               no
# 4  question-mission13-agent0                  186               no
#
#   question0-confidence question0-elapsedTime              question1-ref  \
# 0               fairly                 97353  question-mission85-agent0
# 1                 null                  null                       null
# 2               fairly                183265  question-mission85-agent0
# 3           completely                127270  question-mission85-agent0
# 4             slightly                 93320  question-mission95-agent0
#
#   question1-total-cost question1-answer question1-confidence  \
# 0                  108              yes           completely
# 1                 null             null                 null
# 2                  108              yes           completely
# 3                  108              yes           completely
# 4                  138              yes             somewhat
#
#   question1-elapsedTime              question2-ref question2-total-cost  \
# 0                 14373  question-mission26-agent0                  155
# 1                  null                       null                 null
# 2                 60012  question-mission26-agent0                  173
# 3                 36854  question-mission26-agent0                  155
# 4                 25818  question-mission75-agent0                  181
#
#   question2-answer question2-confidence question2-elapsedTime  \
# 0               no           completely                 39149
# 1             null                 null                  null
# 2              yes               fairly                 80461
# 3               no             somewhat                 80468
# 4               no           completely                 35327
#
#                question3-ref  question3-total-cost question3-answer  \
# 0  question-mission74-agent2                   159              yes
# 1  question-mission74-agent2                   211              yes
# 2  question-mission74-agent2                   199              yes
# 3  question-mission74-agent2                   199              yes
# 4  question-mission54-agent0                   303               no
#
#   question3-confidence  question3-elapsedTime
# 0             somewhat                 146259
# 1             somewhat                  91468
# 2               fairly                  73092
# 3               fairly                  24337
# 4           completely                  62365

# %%
df_assignments_expr.head()
# Out:
#    HIT Index                          HIT ID                      HITType ID  \
# 0          0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ  3K1KXTVNBMKZJI3PCNEA4YMJWSSM1N
# 1          0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ  3K1KXTVNBMKZJI3PCNEA4YMJWSSM1N
# 2          0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ  3K1KXTVNBMKZJI3PCNEA4YMJWSSM1N
# 3          0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ  3K1KXTVNBMKZJI3PCNEA4YMJWSSM1N
# 4          1  3HJ1EVZS2QI20ALDA7JTUA20NXFR3V  3K1KXTVNBMKZJI3PCNEA4YMJWSSM1N
#
#                     Assignment ID       Worker ID  Total Time (seconds)  \
# 0  34FNN24DCP8HYAIXSN4I5NP63IDY5B  A3UF6XXFFRR237                  1018
# 1  31T4R4OBOVFJIBVBKO1Q6GBJR0U7CV  A3D2GO0IFRFN6R                   861
# 2  3D3VGR7TA3E5NUJ709OVIUYPMZER3J   AY7WPVKHVNBLG                  1442
# 3  3TEM0PF1Q8WF5S15ZLBSB7JE4MD0D1    AEWPAZBYA7XE                   885
# 4  3KKG4CDWKLXK1Q6P66TS1EQ1UEK94H  A1F34ZP6YNI98F                   537
#
#                            question0-ref  question0-total-cost  \
# 0  question-mission12-agent0-explanation                 206.0
# 1  question-mission12-agent0-explanation                 206.0
# 2  question-mission12-agent0-explanation                 206.0
# 3  question-mission12-agent0-explanation                 206.0
# 4  question-mission13-agent0-explanation                 393.0
#
#   question0-answer question0-confidence  question0-elapsedTime  \
# 0              yes               fairly                 235538
# 1              yes           completely                 288066
# 2              yes             somewhat                 294507
# 3              yes           completely                 444698
# 4               no               fairly                 129827
#
#                            question1-ref  question1-total-cost  \
# 0  question-mission85-agent0-explanation                    10
# 1  question-mission85-agent0-explanation                   108
# 2  question-mission85-agent0-explanation                   108
# 3  question-mission85-agent0-explanation                   108
# 4  question-mission95-agent0-explanation                   108
#
#   question1-answer question1-confidence  question1-elapsedTime  \
# 0               no           completely                  28398
# 1              yes           completely                  38835
# 2              yes           completely                  43657
# 3              yes           completely                  60877
# 4              yes               fairly                  57762
#
#                            question2-ref  question2-total-cost  \
# 0  question-mission26-agent0-explanation                 173.0
# 1  question-mission26-agent0-explanation                 173.0
# 2  question-mission26-agent0-explanation                 173.0
# 3  question-mission26-agent0-explanation                 173.0
# 4  question-mission75-agent0-explanation                 335.0
#
#   question2-answer question2-confidence  question2-elapsedTime  \
# 0               no           completely                 100612
# 1               no           completely                  82678
# 2              yes             slightly                 124385
# 3               no           completely                  67961
# 4              yes               fairly                 190742
#
#                            question3-ref  question3-total-cost  \
# 0  question-mission74-agent2-explanation                 199.0
# 1  question-mission74-agent2-explanation                 199.0
# 2  question-mission74-agent2-explanation                 199.0
# 3  question-mission74-agent2-explanation                 199.0
# 4  question-mission54-agent0-explanation                 303.0
#
#   question3-answer question3-confidence  question3-elapsedTime
# 0               no           completely                 146051
# 1               no           completely                  69736
# 2               no             somewhat                  98455
# 3               no           completely                  45301
# 4              yes             somewhat                  51402

# %%
df_answers_ctrl.head()
# Out:
#                          ref  total-cost answer
# 0  question-mission59-agent4         708     no
# 1  question-mission80-agent0         108    yes
# 2  question-mission42-agent7         709     no
# 3  question-mission66-agent0         875    yes
# 4  question-mission45-agent7         220     no

# %%
df_answers_expr.head()
# Out:
#                                      ref  total-cost answer
# 0  question-mission12-agent0-explanation         206    yes
# 1  question-mission85-agent0-explanation         108    yes
# 2  question-mission26-agent0-explanation         173    yes
# 3  question-mission74-agent2-explanation         199     no
# 4  question-mission13-agent0-explanation         393    yes

# %%
# Create columns for all data types for all questions
# Columns are named in the format: question[i]-[data_type_name]
def create_columns(data_types, num_questions):
    columns = []
    for i in range(num_questions):
        for data_type in data_types:
            columns.append('question' + str(i) + "-" + data_type)
    return columns

# %%
# Create columns for a single data type for all questions
# Columns are named in the format: question[i]-[data_type_name]
def create_columns_for_data_type(data_type, num_questions):
    return ['question' + str(i) + '-' + data_type for i in range(num_questions)]

# %%
# Remove any assignment (i.e., any row) that contains missing data of a given data type of any question
def remove_assignments_with_missing_data(df_assignments, data_type, num_questions):
    columns = create_columns_for_data_type(data_type, num_questions)
    non_numeric_df_assignments_columns = df_assignments.select_dtypes(exclude=['int','float']).columns
    non_numeric_columns = [column for column in columns if column in non_numeric_df_assignments_columns]
    for column in non_numeric_columns:
        df_assignments = df_assignments[df_assignments[column] != 'null']
    return df_assignments

# %%
def set_columns_type_to_numeric(df_assignments, data_type, num_questions):
    columns = create_columns_for_data_type(data_type, num_questions)
    df_assignments[columns] = df_assignments[columns].apply(pd.to_numeric)
    return df_assignments

# %%
df_assignments_ctrl = remove_assignments_with_missing_data(df_assignments_ctrl, 'total-cost', 4)
df_assignments_ctrl.head()
# Out:
#    HIT Index                          HIT ID                      HITType ID  \
# 0          0  3BA7SXOG1LPO17RJMOEPLRAB3IOR82  35280GTXAPQ35X4ZWHDC3QI4GWDOVS
# 2          0  3BA7SXOG1LPO17RJMOEPLRAB3IOR82  35280GTXAPQ35X4ZWHDC3QI4GWDOVS
# 3          0  3BA7SXOG1LPO17RJMOEPLRAB3IOR82  35280GTXAPQ35X4ZWHDC3QI4GWDOVS
# 4          1  3UOMW19E6F518NJY6THRKC1Y1RRC5M  35280GTXAPQ35X4ZWHDC3QI4GWDOVS
# 5          1  3UOMW19E6F518NJY6THRKC1Y1RRC5M  35280GTXAPQ35X4ZWHDC3QI4GWDOVS
#
#                     Assignment ID       Worker ID  Total Time (seconds)  \
# 0  3PWWM24LHVXAK78SX04Q83YSQOR28Y   A7P3R1AIA4TVV                  1106
# 2  35BLDD71I9WY1U7HU0OENSS7MVTVZ6  A272X64FOZFYLB                   722
# 3  3WOKGM4L74F69PSUPUP8M1VD8WUO0O  A1DMXEJGJY02E1                   721
# 4  3P4RDNWND853F9IDD7M9K9ENVWLIJE  A38Z99XF4NDNH0                   471
# 5  3HRMW88U19PI9M7ICEAVUX68DWYM0Q  A1K5ILJMG439M5                  1051
#
#                question0-ref question0-total-cost question0-answer  \
# 0  question-mission12-agent0                  181              yes
# 2  question-mission12-agent0                  206              yes
# 3  question-mission12-agent0                189.8               no
# 4  question-mission13-agent0                  186               no
# 5  question-mission13-agent0                  393              yes
#
#   question0-confidence question0-elapsedTime              question1-ref  \
# 0               fairly                 97353  question-mission85-agent0
# 2               fairly                183265  question-mission85-agent0
# 3           completely                127270  question-mission85-agent0
# 4             slightly                 93320  question-mission95-agent0
# 5             somewhat                260413  question-mission95-agent0
#
#   question1-total-cost question1-answer question1-confidence  \
# 0                  108              yes           completely
# 2                  108              yes           completely
# 3                  108              yes           completely
# 4                  138              yes             somewhat
# 5                  108              yes               fairly
#
#   question1-elapsedTime              question2-ref question2-total-cost  \
# 0                 14373  question-mission26-agent0                  155
# 2                 60012  question-mission26-agent0                  173
# 3                 36854  question-mission26-agent0                  155
# 4                 25818  question-mission75-agent0                  181
# 5                 61612  question-mission75-agent0                  335
#
#   question2-answer question2-confidence question2-elapsedTime  \
# 0               no           completely                 39149
# 2              yes               fairly                 80461
# 3               no             somewhat                 80468
# 4               no           completely                 35327
# 5              yes             somewhat                139476
#
#                question3-ref  question3-total-cost question3-answer  \
# 0  question-mission74-agent2                   159              yes
# 2  question-mission74-agent2                   199              yes
# 3  question-mission74-agent2                   199              yes
# 4  question-mission54-agent0                   303               no
# 5  question-mission54-agent0                   303               no
#
#   question3-confidence  question3-elapsedTime
# 0             somewhat                 146259
# 2               fairly                  73092
# 3               fairly                  24337
# 4           completely                  62365
# 5             slightly                  90964

# %%
df_assignments_expr = remove_assignments_with_missing_data(df_assignments_expr, 'total-cost', 4)
df_assignments_expr.head()
# Out:
#    HIT Index                          HIT ID                      HITType ID  \
# 0          0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ  3K1KXTVNBMKZJI3PCNEA4YMJWSSM1N
# 1          0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ  3K1KXTVNBMKZJI3PCNEA4YMJWSSM1N
# 2          0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ  3K1KXTVNBMKZJI3PCNEA4YMJWSSM1N
# 3          0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ  3K1KXTVNBMKZJI3PCNEA4YMJWSSM1N
# 4          1  3HJ1EVZS2QI20ALDA7JTUA20NXFR3V  3K1KXTVNBMKZJI3PCNEA4YMJWSSM1N
#
#                     Assignment ID       Worker ID  Total Time (seconds)  \
# 0  34FNN24DCP8HYAIXSN4I5NP63IDY5B  A3UF6XXFFRR237                  1018
# 1  31T4R4OBOVFJIBVBKO1Q6GBJR0U7CV  A3D2GO0IFRFN6R                   861
# 2  3D3VGR7TA3E5NUJ709OVIUYPMZER3J   AY7WPVKHVNBLG                  1442
# 3  3TEM0PF1Q8WF5S15ZLBSB7JE4MD0D1    AEWPAZBYA7XE                   885
# 4  3KKG4CDWKLXK1Q6P66TS1EQ1UEK94H  A1F34ZP6YNI98F                   537
#
#                            question0-ref  question0-total-cost  \
# 0  question-mission12-agent0-explanation                 206.0
# 1  question-mission12-agent0-explanation                 206.0
# 2  question-mission12-agent0-explanation                 206.0
# 3  question-mission12-agent0-explanation                 206.0
# 4  question-mission13-agent0-explanation                 393.0
#
#   question0-answer question0-confidence  question0-elapsedTime  \
# 0              yes               fairly                 235538
# 1              yes           completely                 288066
# 2              yes             somewhat                 294507
# 3              yes           completely                 444698
# 4               no               fairly                 129827
#
#                            question1-ref  question1-total-cost  \
# 0  question-mission85-agent0-explanation                    10
# 1  question-mission85-agent0-explanation                   108
# 2  question-mission85-agent0-explanation                   108
# 3  question-mission85-agent0-explanation                   108
# 4  question-mission95-agent0-explanation                   108
#
#   question1-answer question1-confidence  question1-elapsedTime  \
# 0               no           completely                  28398
# 1              yes           completely                  38835
# 2              yes           completely                  43657
# 3              yes           completely                  60877
# 4              yes               fairly                  57762
#
#                            question2-ref  question2-total-cost  \
# 0  question-mission26-agent0-explanation                 173.0
# 1  question-mission26-agent0-explanation                 173.0
# 2  question-mission26-agent0-explanation                 173.0
# 3  question-mission26-agent0-explanation                 173.0
# 4  question-mission75-agent0-explanation                 335.0
#
#   question2-answer question2-confidence  question2-elapsedTime  \
# 0               no           completely                 100612
# 1               no           completely                  82678
# 2              yes             slightly                 124385
# 3               no           completely                  67961
# 4              yes               fairly                 190742
#
#                            question3-ref  question3-total-cost  \
# 0  question-mission74-agent2-explanation                 199.0
# 1  question-mission74-agent2-explanation                 199.0
# 2  question-mission74-agent2-explanation                 199.0
# 3  question-mission74-agent2-explanation                 199.0
# 4  question-mission54-agent0-explanation                 303.0
#
#   question3-answer question3-confidence  question3-elapsedTime
# 0               no           completely                 146051
# 1               no           completely                  69736
# 2               no             somewhat                  98455
# 3               no           completely                  45301
# 4              yes             somewhat                  51402

# %%
# Compute accuracy of total-cost (in %error) and answer (correct/incorrect) for each question, from each worker
def compute_accuracy(df_assignments, df_answers):
    # Accuracy of total-cost (%error) and answer (correct/incorrect) from workers
    accuracy_columns = create_columns(['ref', 'total-cost', 'answer'], 4)
    df_accuracy = pd.DataFrame(columns=accuracy_columns)
    
    # Data columns of interest for each question: ref, total-cost, answer
    ref_columns = create_columns_for_data_type('ref', 4)
    total_cost_columns = create_columns_for_data_type('total-cost', 4)
    answer_columns = create_columns_for_data_type('answer', 4)
    
    df_assignments = set_columns_type_to_numeric(df_assignments, 'total-cost', 4)
    
    for index, row in df_assignments.iterrows():
        # ref: question-mission[i]-agent[j] is shared between assignments and answerKey tables
        df_answer_key = df_answers[df_answers.ref.isin(row[ref_columns])]

        # Accuracy of total-cost and answer from workers
        worker_acc_dict = {'HIT ID': row['HIT ID'], 'Worker ID': row['Worker ID']}

        for i in range(4):
            ref_column = ref_columns[i] # question[i]-ref
            total_cost_column = total_cost_columns[i] # question[i]-total-cost
            answer_column = answer_columns[i] # question[i]-answer

            # total-cost and %error
            worker_total_cost = row[total_cost_column]
            correct_total_cost = df_answer_key[df_answer_key.ref == row[ref_column]].iloc[0]['total-cost']
            total_cost_err = abs((correct_total_cost - worker_total_cost) / correct_total_cost)

            # answer and correct/incorrect
            worker_answer = row[answer_column]
            correct_answer = df_answer_key[df_answer_key.ref == row[ref_column]].iloc[0]['answer']
            answer_acc = 1 if worker_answer == correct_answer else 0

            # Accuracy dict
            worker_acc_dict[ref_column] = row[ref_column]
            worker_acc_dict[total_cost_column] = total_cost_err
            worker_acc_dict[answer_column] = answer_acc

        df_accuracy = df_accuracy.append(worker_acc_dict, ignore_index=True)
    return df_accuracy

# %%
df_accuracy_ctrl = compute_accuracy(df_assignments_ctrl, df_answers_ctrl)
print(df_accuracy_ctrl)
# Out:
#                 question0-ref  question0-total-cost  question0-answer  \
# 0   question-mission12-agent0              0.121359               1.0
# 1   question-mission12-agent0              0.000000               1.0
# 2   question-mission12-agent0              0.078641               0.0
# 3   question-mission13-agent0              0.526718               0.0
# 4   question-mission13-agent0              0.000000               1.0
# 5   question-mission13-agent0              0.000000               1.0
# 6   question-mission24-agent0              0.000000               0.0
# 7   question-mission24-agent0              0.000000               1.0
# 8   question-mission24-agent0              0.000000               1.0
# 9   question-mission24-agent0              0.000000               1.0
# 10  question-mission25-agent2              0.307317               0.0
# 11  question-mission25-agent2              0.000000               0.0
# 12  question-mission25-agent2              0.439024               0.0
# 13  question-mission34-agent1              0.000000               1.0
# 14  question-mission34-agent1              0.061856               1.0
# 15  question-mission34-agent1              0.061856               0.0
# 16  question-mission35-agent0              0.000000               1.0
# 17  question-mission35-agent0              0.000000               1.0
# 18  question-mission35-agent0              0.000000               1.0
# 19  question-mission45-agent7              0.000000               1.0
# 20  question-mission45-agent7              0.040909               0.0
# 21  question-mission45-agent7              0.000000               1.0
# 22  question-mission46-agent7              0.000000               0.0
# 23  question-mission46-agent7              0.000000               0.0
# 24  question-mission46-agent7              0.000000               0.0
# 25  question-mission56-agent0              0.352273               1.0
# 26  question-mission56-agent0              0.000000               1.0
# 27  question-mission56-agent0              0.000000               1.0
# 28  question-mission57-agent0              0.121622               1.0
# 29  question-mission57-agent0              0.000000               1.0
# 30  question-mission57-agent0              0.000000               0.0
#
#                 question1-ref  question1-total-cost  question1-answer  \
# 0   question-mission85-agent0              0.000000               1.0
# 1   question-mission85-agent0              0.000000               1.0
# 2   question-mission85-agent0              0.000000               1.0
# 3   question-mission95-agent0              0.277778               1.0
# 4   question-mission95-agent0              0.000000               1.0
# 5   question-mission95-agent0              0.000000               1.0
# 6   question-mission94-agent0              4.092593               0.0
# 7   question-mission94-agent0              0.000000               1.0
# 8   question-mission94-agent0              0.000000               1.0
# 9   question-mission94-agent0              0.000000               1.0
# 10  question-mission82-agent0              0.000000               1.0
# 11  question-mission82-agent0              0.000000               1.0
# 12  question-mission82-agent0              0.000000               1.0
# 13  question-mission84-agent0              0.000000               1.0
# 14  question-mission84-agent0              0.000000               1.0
# 15  question-mission84-agent0              0.000000               1.0
# 16  question-mission92-agent0              0.000000               1.0
# 17  question-mission92-agent0              0.000000               1.0
# 18  question-mission92-agent0              0.000000               1.0
# 19  question-mission81-agent0              0.000000               1.0
# 20  question-mission81-agent0              0.000000               1.0
# 21  question-mission81-agent0              0.000000               1.0
# 22  question-mission91-agent1              0.000000               1.0
# 23  question-mission91-agent1              0.310881               1.0
# 24  question-mission91-agent1              0.000000               1.0
# 25  question-mission83-agent1              0.000000               1.0
# 26  question-mission83-agent1              0.000000               1.0
# 27  question-mission83-agent1              0.000000               1.0
# 28  question-mission93-agent0              0.000000               1.0
# 29  question-mission93-agent0              0.000000               1.0
# 30  question-mission93-agent0              0.000000               1.0
#
#                 question2-ref  question2-total-cost  question2-answer  \
# 0   question-mission26-agent0              0.104046               0.0
# 1   question-mission26-agent0              0.000000               1.0
# 2   question-mission26-agent0              0.104046               0.0
# 3   question-mission75-agent0              0.459701               0.0
# 4   question-mission75-agent0              0.000000               1.0
# 5   question-mission75-agent0              0.000000               1.0
# 6   question-mission37-agent0              0.000000               1.0
# 7   question-mission37-agent0              0.000000               1.0
# 8   question-mission37-agent0              0.000000               0.0
# 9   question-mission37-agent0              0.000000               1.0
# 10  question-mission52-agent7              0.000000               0.0
# 11  question-mission52-agent7              0.000000               0.0
# 12  question-mission52-agent7              0.000000               0.0
# 13  question-mission14-agent0              0.239521               0.0
# 14  question-mission14-agent0              0.023952               1.0
# 15  question-mission14-agent0              0.125749               1.0
# 16  question-mission15-agent0              0.000000               1.0
# 17  question-mission15-agent0              0.000000               0.0
# 18  question-mission15-agent0              0.000000               1.0
# 19  question-mission69-agent0              0.000000               0.0
# 20  question-mission69-agent0              0.000000               1.0
# 21  question-mission69-agent0              0.081448               1.0
# 22  question-mission63-agent8              0.000000               1.0
# 23  question-mission63-agent8              0.265487               1.0
# 24  question-mission63-agent8              0.000000               1.0
# 25  question-mission79-agent0              0.000000               1.0
# 26  question-mission79-agent0              0.000000               1.0
# 27  question-mission79-agent0              0.000000               1.0
# 28  question-mission47-agent6              0.000000               1.0
# 29  question-mission47-agent6              0.000000               0.0
# 30  question-mission47-agent6              0.000000               1.0
#
#                 question3-ref  question3-total-cost  question3-answer  \
# 0   question-mission74-agent2              0.201005               0.0
# 1   question-mission74-agent2              0.000000               0.0
# 2   question-mission74-agent2              0.000000               0.0
# 3   question-mission54-agent0              0.000000               0.0
# 4   question-mission54-agent0              0.000000               0.0
# 5   question-mission54-agent0              0.617162               1.0
# 6   question-mission10-agent0              0.000000               0.0
# 7   question-mission10-agent0              0.000000               1.0
# 8   question-mission10-agent0              0.000000               1.0
# 9   question-mission10-agent0              0.000000               1.0
# 10  question-mission11-agent0              0.000000               0.0
# 11  question-mission11-agent0              0.000000               1.0
# 12  question-mission11-agent0              0.000000               1.0
# 13  question-mission48-agent6              0.017647               0.0
# 14  question-mission48-agent6              0.082353               1.0
# 15  question-mission48-agent6              0.052941               0.0
# 16  question-mission31-agent6              0.000000               1.0
# 17  question-mission31-agent6              0.000000               1.0
# 18  question-mission31-agent6              0.000000               1.0
# 19   question-mission5-agent0              0.000000               0.0
# 20   question-mission5-agent0              0.040161               1.0
# 21   question-mission5-agent0              0.000000               1.0
# 22  question-mission64-agent1              0.000000               0.0
# 23  question-mission64-agent1              0.199336               0.0
# 24  question-mission64-agent1              0.000000               0.0
# 25   question-mission8-agent0              0.000000               1.0
# 26   question-mission8-agent0              0.000000               1.0
# 27   question-mission8-agent0              0.000000               1.0
# 28   question-mission6-agent1              0.000000               0.0
# 29   question-mission6-agent1              0.000000               0.0
# 30   question-mission6-agent1              0.000000               0.0
#
#                             HIT ID       Worker ID
# 0   3BA7SXOG1LPO17RJMOEPLRAB3IOR82   A7P3R1AIA4TVV
# 1   3BA7SXOG1LPO17RJMOEPLRAB3IOR82  A272X64FOZFYLB
# 2   3BA7SXOG1LPO17RJMOEPLRAB3IOR82  A1DMXEJGJY02E1
# 3   3UOMW19E6F518NJY6THRKC1Y1RRC5M  A38Z99XF4NDNH0
# 4   3UOMW19E6F518NJY6THRKC1Y1RRC5M  A1K5ILJMG439M5
# 5   3UOMW19E6F518NJY6THRKC1Y1RRC5M  A19ZWBQT8A3LIR
# 6   3W1K7D6QSDGG5WBHZHSCYW2BK52BZO  A3MLUEOP3CCLXL
# 7   3W1K7D6QSDGG5WBHZHSCYW2BK52BZO  A1FYWSPNO7KN1O
# 8   3W1K7D6QSDGG5WBHZHSCYW2BK52BZO  A38NFX88VZDMJ3
# 9   3W1K7D6QSDGG5WBHZHSCYW2BK52BZO  A17Q4QN6UE0EZC
# 10  36QZ6V158BCY0JY94GFZ7TXWMBBSUJ   AQAXDL1INQC9Q
# 11  36QZ6V158BCY0JY94GFZ7TXWMBBSUJ  A1VAL7L9L79IN0
# 12  36QZ6V158BCY0JY94GFZ7TXWMBBSUJ  A2QPMJ4GADLUW2
# 13  3CRWSLD91M30PJ17OX74WE61C40MOR   A4LCG4MSNJRUF
# 14  3CRWSLD91M30PJ17OX74WE61C40MOR  A1A1A9UHNQCI9Y
# 15  3CRWSLD91M30PJ17OX74WE61C40MOR  A3UN1F1EOHKKE6
# 16  3ABAOCJ4RA33AVEN3AZ8LJ11R5KMQ1  A37S96RT1P1IT2
# 17  3ABAOCJ4RA33AVEN3AZ8LJ11R5KMQ1   A3GAQNTZ1V1VO
# 18  3ABAOCJ4RA33AVEN3AZ8LJ11R5KMQ1   AY8V73VAPWWIQ
# 19  32XN26MTX1IVGKR3M04E60VUEYU0LH  A3CXK1KSRGU27V
# 20  32XN26MTX1IVGKR3M04E60VUEYU0LH   AVBRJBJONL47I
# 21  32XN26MTX1IVGKR3M04E60VUEYU0LH  A1SX8IVV82M0LW
# 22  33N1S8XHHOKFSYTPXKZNSKP2YZH1ZD  A31681CCEVDIH3
# 23  33N1S8XHHOKFSYTPXKZNSKP2YZH1ZD   ARWF605I7RWM7
# 24  33N1S8XHHOKFSYTPXKZNSKP2YZH1ZD  A2JP9IKRHNLRPI
# 25  3Y40HMYLL3H6W0K8YQLM61EO1ZMXUN  A2N2GFB33ZMYGF
# 26  3Y40HMYLL3H6W0K8YQLM61EO1ZMXUN  A2GFU1QB3HGIX7
# 27  3Y40HMYLL3H6W0K8YQLM61EO1ZMXUN   ARI1EMAHUA9PO
# 28  302OLP89D16YETVF1P88SNHKTEBACR  A2I960JYUZ8KAV
# 29  302OLP89D16YETVF1P88SNHKTEBACR  A2TLN8489YGY81
# 30  302OLP89D16YETVF1P88SNHKTEBACR  A2QWTQ4I70BRWO

# %%
df_accuracy_expr = compute_accuracy(df_assignments_expr, df_answers_expr)
print(df_accuracy_expr)
# Out:
#                             question0-ref  question0-total-cost  \
# 0   question-mission12-agent0-explanation              0.000000
# 1   question-mission12-agent0-explanation              0.000000
# 2   question-mission12-agent0-explanation              0.000000
# 3   question-mission12-agent0-explanation              0.000000
# 4   question-mission13-agent0-explanation              0.000000
# 5   question-mission13-agent0-explanation              0.000000
# 6   question-mission13-agent0-explanation              0.000000
# 7   question-mission24-agent0-explanation              0.000000
# 8   question-mission24-agent0-explanation              0.166667
# 9   question-mission24-agent0-explanation              2.098765
# 10  question-mission24-agent0-explanation              0.000000
# 11  question-mission25-agent2-explanation              0.000000
# 12  question-mission25-agent2-explanation              0.307317
# 13  question-mission25-agent2-explanation              0.000000
# 14  question-mission34-agent1-explanation              0.000000
# 15  question-mission34-agent1-explanation              0.000000
# 16  question-mission34-agent1-explanation              0.000000
# 17  question-mission35-agent0-explanation              0.000000
# 18  question-mission35-agent0-explanation              0.000000
# 19  question-mission35-agent0-explanation              0.335669
# 20  question-mission45-agent7-explanation              0.000000
# 21  question-mission45-agent7-explanation              0.000000
# 22  question-mission45-agent7-explanation              0.027273
# 23  question-mission46-agent7-explanation              0.000000
# 24  question-mission46-agent7-explanation              0.000000
# 25  question-mission46-agent7-explanation              0.000000
#
#     question0-answer                          question1-ref  \
# 0                1.0  question-mission85-agent0-explanation
# 1                1.0  question-mission85-agent0-explanation
# 2                1.0  question-mission85-agent0-explanation
# 3                1.0  question-mission85-agent0-explanation
# 4                0.0  question-mission95-agent0-explanation
# 5                0.0  question-mission95-agent0-explanation
# 6                0.0  question-mission95-agent0-explanation
# 7                1.0  question-mission94-agent0-explanation
# 8                1.0  question-mission94-agent0-explanation
# 9                1.0  question-mission94-agent0-explanation
# 10               1.0  question-mission94-agent0-explanation
# 11               1.0  question-mission82-agent0-explanation
# 12               0.0  question-mission82-agent0-explanation
# 13               0.0  question-mission82-agent0-explanation
# 14               1.0  question-mission84-agent0-explanation
# 15               1.0  question-mission84-agent0-explanation
# 16               0.0  question-mission84-agent0-explanation
# 17               1.0  question-mission92-agent0-explanation
# 18               1.0  question-mission92-agent0-explanation
# 19               0.0  question-mission92-agent0-explanation
# 20               0.0  question-mission81-agent0-explanation
# 21               1.0  question-mission81-agent0-explanation
# 22               1.0  question-mission81-agent0-explanation
# 23               1.0  question-mission91-agent0-explanation
# 24               1.0  question-mission91-agent0-explanation
# 25               1.0  question-mission91-agent0-explanation
#
#     question1-total-cost  question1-answer  \
# 0               0.907407               0.0
# 1               0.000000               1.0
# 2               0.000000               1.0
# 3               0.000000               1.0
# 4               0.000000               1.0
# 5               0.000000               1.0
# 6               0.000000               1.0
# 7               0.000000               1.0
# 8               0.768519               1.0
# 9               0.000000               1.0
# 10              0.000000               1.0
# 11              0.000000               1.0
# 12              0.000000               1.0
# 13              0.000000               1.0
# 14              0.000000               1.0
# 15              0.000000               1.0
# 16              0.000000               1.0
# 17              0.000000               1.0
# 18              0.000000               1.0
# 19              0.000000               1.0
# 20              1.962963               1.0
# 21              0.000000               1.0
# 22              0.000000               1.0
# 23              0.000000               1.0
# 24              0.000000               1.0
# 25              0.000000               1.0
#
#                             question2-ref  question2-total-cost  \
# 0   question-mission26-agent0-explanation              0.000000
# 1   question-mission26-agent0-explanation              0.000000
# 2   question-mission26-agent0-explanation              0.000000
# 3   question-mission26-agent0-explanation              0.000000
# 4   question-mission75-agent0-explanation              0.000000
# 5   question-mission75-agent0-explanation              0.059701
# 6   question-mission75-agent0-explanation              1.373134
# 7   question-mission37-agent0-explanation              0.000000
# 8   question-mission37-agent0-explanation              0.165605
# 9   question-mission37-agent0-explanation              0.000000
# 10  question-mission37-agent0-explanation              0.000000
# 11  question-mission52-agent7-explanation              0.000000
# 12  question-mission52-agent7-explanation              0.000000
# 13  question-mission52-agent7-explanation              0.000000
# 14  question-mission14-agent0-explanation              0.000000
# 15  question-mission14-agent0-explanation              0.000000
# 16  question-mission14-agent0-explanation              0.000000
# 17  question-mission15-agent0-explanation              0.000000
# 18  question-mission15-agent0-explanation              0.000000
# 19  question-mission15-agent0-explanation              0.035391
# 20  question-mission69-agent0-explanation              0.000000
# 21  question-mission69-agent0-explanation              0.000000
# 22  question-mission69-agent0-explanation              0.045249
# 23  question-mission63-agent8-explanation              0.000000
# 24  question-mission63-agent8-explanation              0.000000
# 25  question-mission63-agent8-explanation              0.000000
#
#     question2-answer                          question3-ref  \
# 0                0.0  question-mission74-agent2-explanation
# 1                0.0  question-mission74-agent2-explanation
# 2                1.0  question-mission74-agent2-explanation
# 3                0.0  question-mission74-agent2-explanation
# 4                1.0  question-mission54-agent0-explanation
# 5                0.0  question-mission54-agent0-explanation
# 6                1.0  question-mission54-agent0-explanation
# 7                1.0  question-mission10-agent0-explanation
# 8                1.0  question-mission10-agent0-explanation
# 9                1.0  question-mission10-agent0-explanation
# 10               0.0  question-mission10-agent0-explanation
# 11               0.0  question-mission11-agent0-explanation
# 12               0.0  question-mission11-agent0-explanation
# 13               1.0  question-mission11-agent0-explanation
# 14               1.0  question-mission48-agent6-explanation
# 15               1.0  question-mission48-agent6-explanation
# 16               1.0  question-mission48-agent6-explanation
# 17               1.0  question-mission31-agent6-explanation
# 18               1.0  question-mission31-agent6-explanation
# 19               0.0  question-mission31-agent6-explanation
# 20               1.0   question-mission5-agent0-explanation
# 21               1.0   question-mission5-agent0-explanation
# 22               1.0   question-mission5-agent0-explanation
# 23               1.0  question-mission64-agent1-explanation
# 24               1.0  question-mission64-agent1-explanation
# 25               1.0  question-mission64-agent1-explanation
#
#     question3-total-cost  question3-answer                          HIT ID  \
# 0               0.000000               1.0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ
# 1               0.000000               1.0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ
# 2               0.000000               1.0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ
# 3               0.000000               1.0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ
# 4               0.000000               1.0  3HJ1EVZS2QI20ALDA7JTUA20NXFR3V
# 5               0.000000               1.0  3HJ1EVZS2QI20ALDA7JTUA20NXFR3V
# 6               0.151815               1.0  3HJ1EVZS2QI20ALDA7JTUA20NXFR3V
# 7               0.000000               1.0  3SSN80MU8ENST4FW4CHK0E5QZ2NXKD
# 8               0.256917               1.0  3SSN80MU8ENST4FW4CHK0E5QZ2NXKD
# 9               0.000000               1.0  3SSN80MU8ENST4FW4CHK0E5QZ2NXKD
# 10              0.000000               1.0  3SSN80MU8ENST4FW4CHK0E5QZ2NXKD
# 11              0.000000               0.0  3X2YVV51PW3BY3OKMXFGTGVKHV31W9
# 12              0.000000               1.0  3X2YVV51PW3BY3OKMXFGTGVKHV31W9
# 13              0.000000               1.0  3X2YVV51PW3BY3OKMXFGTGVKHV31W9
# 14              0.000000               0.0  31JUPBOORP3DY9W6H4HTZF1CXXX8L5
# 15              0.000000               1.0  31JUPBOORP3DY9W6H4HTZF1CXXX8L5
# 16              0.000000               1.0  31JUPBOORP3DY9W6H4HTZF1CXXX8L5
# 17              0.000000               0.0  3WPCIUYH1C7DYH027LU07YPU21VTDE
# 18              0.000000               0.0  3WPCIUYH1C7DYH027LU07YPU21VTDE
# 19              0.040199               0.0  3WPCIUYH1C7DYH027LU07YPU21VTDE
# 20              0.000000               1.0  3A520CCNWPZDBRFTXGE3IBHNEP1EAZ
# 21              0.000000               1.0  3A520CCNWPZDBRFTXGE3IBHNEP1EAZ
# 22              0.004016               1.0  3A520CCNWPZDBRFTXGE3IBHNEP1EAZ
# 23              0.000000               1.0  3ATYLI1PRV1AOBVML0UCGMEK8F4OJY
# 24              0.000000               1.0  3ATYLI1PRV1AOBVML0UCGMEK8F4OJY
# 25              0.000000               1.0  3ATYLI1PRV1AOBVML0UCGMEK8F4OJY
#
#          Worker ID
# 0   A3UF6XXFFRR237
# 1   A3D2GO0IFRFN6R
# 2    AY7WPVKHVNBLG
# 3     AEWPAZBYA7XE
# 4   A1F34ZP6YNI98F
# 5   A2OVX9UW5WANQE
# 6   A3OB6REG5CGHK1
# 7   A2F2DDH12YU4AK
# 8   A1YSYI926BBOHW
# 9   A2NGMLBFZ3YQP5
# 10  A2LCFORIW0NF1S
# 11  A1945USNZHTROX
# 12  A3L0DCUXI7X3A9
# 13  A2RGIULFG1GWF5
# 14  A1160COTUR26JZ
# 15  A1UZXOMO6BS6I2
# 16  A2BL6ZVUM0B9C8
# 17  A3S67QA0SQVPUJ
# 18  A2BW6WD7LZ9EGV
# 19  A1C2T79XTDHE39
# 20  A1PUHCEBSOWETV
# 21  A3MYTEE8WSEQ2Z
# 22  A1DX0Z20W07YOR
# 23  A2OZF756R5JSG4
# 24  A22ON3MIIG0IJA
# 25  A3JTDNRJYVCGQD

# %%
def compute_score(df_assignments, df_answers):
    # Score of answer-confidence combination
    score_columns = create_columns(['ref', 'confidence'], 4)
    df_score = pd.DataFrame(columns=score_columns)

    confidence_abs_scores = {'none': 0, 'slightly': 1, 'somewhat': 2, 'fairly': 3, 'completely': 4}
    
    # Data columns of interest for each question: ref, answer, confidence
    ref_columns = create_columns_for_data_type('ref', 4)
    answer_columns = create_columns_for_data_type('answer', 4)
    confidence_columns = create_columns_for_data_type('confidence', 4)

    for index, row in df_assignments.iterrows():
        # ref: question-mission[i]-agent[j] is shared between assignments and answerKey tables
        df_answer_key = df_answers[df_answers.ref.isin(row[ref_columns])]

        # Score of answer-confidence combination
        worker_score_dict = {'HIT ID': row['HIT ID'], 'Worker ID': row['Worker ID']}

        for i in range(4):
            ref_column = ref_columns[i] # question[i]-ref
            answer_column = answer_columns[i] # question[i]-answer
            confidence_column = confidence_columns[i] # question[i]-confidence

            # answer and correct/incorrect
            worker_answer = row[answer_column]
            correct_answer = df_answer_key[df_answer_key.ref == row[ref_column]].iloc[0]['answer']
            answer_acc = worker_answer == correct_answer

            # confidence and score
            worker_confidence = row[confidence_column]
            score = confidence_abs_scores[worker_confidence] if answer_acc else -1 * confidence_abs_scores[worker_confidence]

            # Score dict
            worker_score_dict[ref_column] = row[ref_column]
            worker_score_dict[confidence_column] = score

        df_score = df_score.append(worker_score_dict, ignore_index=True)
    return df_score

# %%
df_score_ctrl = compute_score(df_assignments_ctrl, df_answers_ctrl)
print(df_score_ctrl)
# Out:
#                 question0-ref  question0-confidence  \
# 0   question-mission12-agent0                   3.0
# 1   question-mission12-agent0                   3.0
# 2   question-mission12-agent0                  -4.0
# 3   question-mission13-agent0                  -1.0
# 4   question-mission13-agent0                   2.0
# 5   question-mission13-agent0                   2.0
# 6   question-mission24-agent0                  -2.0
# 7   question-mission24-agent0                   3.0
# 8   question-mission24-agent0                   3.0
# 9   question-mission24-agent0                   3.0
# 10  question-mission25-agent2                  -3.0
# 11  question-mission25-agent2                  -3.0
# 12  question-mission25-agent2                  -3.0
# 13  question-mission34-agent1                   3.0
# 14  question-mission34-agent1                   0.0
# 15  question-mission34-agent1                  -4.0
# 16  question-mission35-agent0                   2.0
# 17  question-mission35-agent0                   2.0
# 18  question-mission35-agent0                   3.0
# 19  question-mission45-agent7                   2.0
# 20  question-mission45-agent7                  -3.0
# 21  question-mission45-agent7                   4.0
# 22  question-mission46-agent7                  -3.0
# 23  question-mission46-agent7                  -2.0
# 24  question-mission46-agent7                  -3.0
# 25  question-mission56-agent0                   3.0
# 26  question-mission56-agent0                   3.0
# 27  question-mission56-agent0                   2.0
# 28  question-mission57-agent0                   2.0
# 29  question-mission57-agent0                   4.0
# 30  question-mission57-agent0                  -3.0
#
#                 question1-ref  question1-confidence  \
# 0   question-mission85-agent0                   4.0
# 1   question-mission85-agent0                   4.0
# 2   question-mission85-agent0                   4.0
# 3   question-mission95-agent0                   2.0
# 4   question-mission95-agent0                   3.0
# 5   question-mission95-agent0                   3.0
# 6   question-mission94-agent0                  -4.0
# 7   question-mission94-agent0                   4.0
# 8   question-mission94-agent0                   4.0
# 9   question-mission94-agent0                   4.0
# 10  question-mission82-agent0                   4.0
# 11  question-mission82-agent0                   4.0
# 12  question-mission82-agent0                   4.0
# 13  question-mission84-agent0                   4.0
# 14  question-mission84-agent0                   4.0
# 15  question-mission84-agent0                   4.0
# 16  question-mission92-agent0                   4.0
# 17  question-mission92-agent0                   4.0
# 18  question-mission92-agent0                   4.0
# 19  question-mission81-agent0                   4.0
# 20  question-mission81-agent0                   4.0
# 21  question-mission81-agent0                   4.0
# 22  question-mission91-agent1                   4.0
# 23  question-mission91-agent1                   3.0
# 24  question-mission91-agent1                   4.0
# 25  question-mission83-agent1                   4.0
# 26  question-mission83-agent1                   4.0
# 27  question-mission83-agent1                   3.0
# 28  question-mission93-agent0                   4.0
# 29  question-mission93-agent0                   4.0
# 30  question-mission93-agent0                   4.0
#
#                 question2-ref  question2-confidence  \
# 0   question-mission26-agent0                  -4.0
# 1   question-mission26-agent0                   3.0
# 2   question-mission26-agent0                  -2.0
# 3   question-mission75-agent0                  -4.0
# 4   question-mission75-agent0                   2.0
# 5   question-mission75-agent0                   2.0
# 6   question-mission37-agent0                   3.0
# 7   question-mission37-agent0                   4.0
# 8   question-mission37-agent0                  -1.0
# 9   question-mission37-agent0                   3.0
# 10  question-mission52-agent7                  -3.0
# 11  question-mission52-agent7                  -3.0
# 12  question-mission52-agent7                  -3.0
# 13  question-mission14-agent0                  -2.0
# 14  question-mission14-agent0                   3.0
# 15  question-mission14-agent0                   4.0
# 16  question-mission15-agent0                   2.0
# 17  question-mission15-agent0                  -1.0
# 18  question-mission15-agent0                   4.0
# 19  question-mission69-agent0                  -1.0
# 20  question-mission69-agent0                   2.0
# 21  question-mission69-agent0                   3.0
# 22  question-mission63-agent8                   3.0
# 23  question-mission63-agent8                   2.0
# 24  question-mission63-agent8                   2.0
# 25  question-mission79-agent0                   3.0
# 26  question-mission79-agent0                   4.0
# 27  question-mission79-agent0                   2.0
# 28  question-mission47-agent6                   1.0
# 29  question-mission47-agent6                  -4.0
# 30  question-mission47-agent6                   3.0
#
#                 question3-ref  question3-confidence  \
# 0   question-mission74-agent2                  -2.0
# 1   question-mission74-agent2                  -3.0
# 2   question-mission74-agent2                  -3.0
# 3   question-mission54-agent0                  -4.0
# 4   question-mission54-agent0                  -1.0
# 5   question-mission54-agent0                   4.0
# 6   question-mission10-agent0                  -2.0
# 7   question-mission10-agent0                   3.0
# 8   question-mission10-agent0                   3.0
# 9   question-mission10-agent0                   3.0
# 10  question-mission11-agent0                  -3.0
# 11  question-mission11-agent0                   2.0
# 12  question-mission11-agent0                   4.0
# 13  question-mission48-agent6                  -3.0
# 14  question-mission48-agent6                   2.0
# 15  question-mission48-agent6                  -3.0
# 16  question-mission31-agent6                   1.0
# 17  question-mission31-agent6                   4.0
# 18  question-mission31-agent6                   4.0
# 19   question-mission5-agent0                  -3.0
# 20   question-mission5-agent0                   1.0
# 21   question-mission5-agent0                   4.0
# 22  question-mission64-agent1                  -3.0
# 23  question-mission64-agent1                  -2.0
# 24  question-mission64-agent1                  -2.0
# 25   question-mission8-agent0                   4.0
# 26   question-mission8-agent0                   4.0
# 27   question-mission8-agent0                   3.0
# 28   question-mission6-agent1                  -2.0
# 29   question-mission6-agent1                  -4.0
# 30   question-mission6-agent1                  -1.0
#
#                             HIT ID       Worker ID
# 0   3BA7SXOG1LPO17RJMOEPLRAB3IOR82   A7P3R1AIA4TVV
# 1   3BA7SXOG1LPO17RJMOEPLRAB3IOR82  A272X64FOZFYLB
# 2   3BA7SXOG1LPO17RJMOEPLRAB3IOR82  A1DMXEJGJY02E1
# 3   3UOMW19E6F518NJY6THRKC1Y1RRC5M  A38Z99XF4NDNH0
# 4   3UOMW19E6F518NJY6THRKC1Y1RRC5M  A1K5ILJMG439M5
# 5   3UOMW19E6F518NJY6THRKC1Y1RRC5M  A19ZWBQT8A3LIR
# 6   3W1K7D6QSDGG5WBHZHSCYW2BK52BZO  A3MLUEOP3CCLXL
# 7   3W1K7D6QSDGG5WBHZHSCYW2BK52BZO  A1FYWSPNO7KN1O
# 8   3W1K7D6QSDGG5WBHZHSCYW2BK52BZO  A38NFX88VZDMJ3
# 9   3W1K7D6QSDGG5WBHZHSCYW2BK52BZO  A17Q4QN6UE0EZC
# 10  36QZ6V158BCY0JY94GFZ7TXWMBBSUJ   AQAXDL1INQC9Q
# 11  36QZ6V158BCY0JY94GFZ7TXWMBBSUJ  A1VAL7L9L79IN0
# 12  36QZ6V158BCY0JY94GFZ7TXWMBBSUJ  A2QPMJ4GADLUW2
# 13  3CRWSLD91M30PJ17OX74WE61C40MOR   A4LCG4MSNJRUF
# 14  3CRWSLD91M30PJ17OX74WE61C40MOR  A1A1A9UHNQCI9Y
# 15  3CRWSLD91M30PJ17OX74WE61C40MOR  A3UN1F1EOHKKE6
# 16  3ABAOCJ4RA33AVEN3AZ8LJ11R5KMQ1  A37S96RT1P1IT2
# 17  3ABAOCJ4RA33AVEN3AZ8LJ11R5KMQ1   A3GAQNTZ1V1VO
# 18  3ABAOCJ4RA33AVEN3AZ8LJ11R5KMQ1   AY8V73VAPWWIQ
# 19  32XN26MTX1IVGKR3M04E60VUEYU0LH  A3CXK1KSRGU27V
# 20  32XN26MTX1IVGKR3M04E60VUEYU0LH   AVBRJBJONL47I
# 21  32XN26MTX1IVGKR3M04E60VUEYU0LH  A1SX8IVV82M0LW
# 22  33N1S8XHHOKFSYTPXKZNSKP2YZH1ZD  A31681CCEVDIH3
# 23  33N1S8XHHOKFSYTPXKZNSKP2YZH1ZD   ARWF605I7RWM7
# 24  33N1S8XHHOKFSYTPXKZNSKP2YZH1ZD  A2JP9IKRHNLRPI
# 25  3Y40HMYLL3H6W0K8YQLM61EO1ZMXUN  A2N2GFB33ZMYGF
# 26  3Y40HMYLL3H6W0K8YQLM61EO1ZMXUN  A2GFU1QB3HGIX7
# 27  3Y40HMYLL3H6W0K8YQLM61EO1ZMXUN   ARI1EMAHUA9PO
# 28  302OLP89D16YETVF1P88SNHKTEBACR  A2I960JYUZ8KAV
# 29  302OLP89D16YETVF1P88SNHKTEBACR  A2TLN8489YGY81
# 30  302OLP89D16YETVF1P88SNHKTEBACR  A2QWTQ4I70BRWO

# %%
df_score_expr = compute_score(df_assignments_expr, df_answers_expr)
print(df_score_expr)
# Out:
#                             question0-ref  question0-confidence  \
# 0   question-mission12-agent0-explanation                   3.0
# 1   question-mission12-agent0-explanation                   4.0
# 2   question-mission12-agent0-explanation                   2.0
# 3   question-mission12-agent0-explanation                   4.0
# 4   question-mission13-agent0-explanation                  -3.0
# 5   question-mission13-agent0-explanation                  -1.0
# 6   question-mission13-agent0-explanation                  -2.0
# 7   question-mission24-agent0-explanation                   4.0
# 8   question-mission24-agent0-explanation                   3.0
# 9   question-mission24-agent0-explanation                   1.0
# 10  question-mission24-agent0-explanation                   1.0
# 11  question-mission25-agent2-explanation                   3.0
# 12  question-mission25-agent2-explanation                  -3.0
# 13  question-mission25-agent2-explanation                  -2.0
# 14  question-mission34-agent1-explanation                   3.0
# 15  question-mission34-agent1-explanation                   3.0
# 16  question-mission34-agent1-explanation                  -3.0
# 17  question-mission35-agent0-explanation                   4.0
# 18  question-mission35-agent0-explanation                   3.0
# 19  question-mission35-agent0-explanation                  -2.0
# 20  question-mission45-agent7-explanation                  -3.0
# 21  question-mission45-agent7-explanation                   3.0
# 22  question-mission45-agent7-explanation                   3.0
# 23  question-mission46-agent7-explanation                   4.0
# 24  question-mission46-agent7-explanation                   4.0
# 25  question-mission46-agent7-explanation                   4.0
#
#                             question1-ref  question1-confidence  \
# 0   question-mission85-agent0-explanation                  -4.0
# 1   question-mission85-agent0-explanation                   4.0
# 2   question-mission85-agent0-explanation                   4.0
# 3   question-mission85-agent0-explanation                   4.0
# 4   question-mission95-agent0-explanation                   3.0
# 5   question-mission95-agent0-explanation                   2.0
# 6   question-mission95-agent0-explanation                   4.0
# 7   question-mission94-agent0-explanation                   4.0
# 8   question-mission94-agent0-explanation                   0.0
# 9   question-mission94-agent0-explanation                   3.0
# 10  question-mission94-agent0-explanation                   4.0
# 11  question-mission82-agent0-explanation                   4.0
# 12  question-mission82-agent0-explanation                   4.0
# 13  question-mission82-agent0-explanation                   3.0
# 14  question-mission84-agent0-explanation                   4.0
# 15  question-mission84-agent0-explanation                   4.0
# 16  question-mission84-agent0-explanation                   4.0
# 17  question-mission92-agent0-explanation                   4.0
# 18  question-mission92-agent0-explanation                   4.0
# 19  question-mission92-agent0-explanation                   4.0
# 20  question-mission81-agent0-explanation                   3.0
# 21  question-mission81-agent0-explanation                   4.0
# 22  question-mission81-agent0-explanation                   4.0
# 23  question-mission91-agent0-explanation                   4.0
# 24  question-mission91-agent0-explanation                   4.0
# 25  question-mission91-agent0-explanation                   3.0
#
#                             question2-ref  question2-confidence  \
# 0   question-mission26-agent0-explanation                  -4.0
# 1   question-mission26-agent0-explanation                  -4.0
# 2   question-mission26-agent0-explanation                   1.0
# 3   question-mission26-agent0-explanation                  -4.0
# 4   question-mission75-agent0-explanation                   3.0
# 5   question-mission75-agent0-explanation                  -1.0
# 6   question-mission75-agent0-explanation                   3.0
# 7   question-mission37-agent0-explanation                   4.0
# 8   question-mission37-agent0-explanation                   1.0
# 9   question-mission37-agent0-explanation                   3.0
# 10  question-mission37-agent0-explanation                  -2.0
# 11  question-mission52-agent7-explanation                  -4.0
# 12  question-mission52-agent7-explanation                  -1.0
# 13  question-mission52-agent7-explanation                   1.0
# 14  question-mission14-agent0-explanation                   4.0
# 15  question-mission14-agent0-explanation                   3.0
# 16  question-mission14-agent0-explanation                   2.0
# 17  question-mission15-agent0-explanation                   4.0
# 18  question-mission15-agent0-explanation                   4.0
# 19  question-mission15-agent0-explanation                  -3.0
# 20  question-mission69-agent0-explanation                   3.0
# 21  question-mission69-agent0-explanation                   4.0
# 22  question-mission69-agent0-explanation                   4.0
# 23  question-mission63-agent8-explanation                   3.0
# 24  question-mission63-agent8-explanation                   4.0
# 25  question-mission63-agent8-explanation                   4.0
#
#                             question3-ref  question3-confidence  \
# 0   question-mission74-agent2-explanation                   4.0
# 1   question-mission74-agent2-explanation                   4.0
# 2   question-mission74-agent2-explanation                   2.0
# 3   question-mission74-agent2-explanation                   4.0
# 4   question-mission54-agent0-explanation                   2.0
# 5   question-mission54-agent0-explanation                   1.0
# 6   question-mission54-agent0-explanation                   2.0
# 7   question-mission10-agent0-explanation                   4.0
# 8   question-mission10-agent0-explanation                   2.0
# 9   question-mission10-agent0-explanation                   3.0
# 10  question-mission10-agent0-explanation                   0.0
# 11  question-mission11-agent0-explanation                  -4.0
# 12  question-mission11-agent0-explanation                   3.0
# 13  question-mission11-agent0-explanation                   1.0
# 14  question-mission48-agent6-explanation                  -2.0
# 15  question-mission48-agent6-explanation                   3.0
# 16  question-mission48-agent6-explanation                   3.0
# 17  question-mission31-agent6-explanation                  -4.0
# 18  question-mission31-agent6-explanation                  -3.0
# 19  question-mission31-agent6-explanation                  -2.0
# 20   question-mission5-agent0-explanation                   3.0
# 21   question-mission5-agent0-explanation                   4.0
# 22   question-mission5-agent0-explanation                   3.0
# 23  question-mission64-agent1-explanation                   4.0
# 24  question-mission64-agent1-explanation                   4.0
# 25  question-mission64-agent1-explanation                   4.0
#
#                             HIT ID       Worker ID
# 0   3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ  A3UF6XXFFRR237
# 1   3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ  A3D2GO0IFRFN6R
# 2   3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ   AY7WPVKHVNBLG
# 3   3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ    AEWPAZBYA7XE
# 4   3HJ1EVZS2QI20ALDA7JTUA20NXFR3V  A1F34ZP6YNI98F
# 5   3HJ1EVZS2QI20ALDA7JTUA20NXFR3V  A2OVX9UW5WANQE
# 6   3HJ1EVZS2QI20ALDA7JTUA20NXFR3V  A3OB6REG5CGHK1
# 7   3SSN80MU8ENST4FW4CHK0E5QZ2NXKD  A2F2DDH12YU4AK
# 8   3SSN80MU8ENST4FW4CHK0E5QZ2NXKD  A1YSYI926BBOHW
# 9   3SSN80MU8ENST4FW4CHK0E5QZ2NXKD  A2NGMLBFZ3YQP5
# 10  3SSN80MU8ENST4FW4CHK0E5QZ2NXKD  A2LCFORIW0NF1S
# 11  3X2YVV51PW3BY3OKMXFGTGVKHV31W9  A1945USNZHTROX
# 12  3X2YVV51PW3BY3OKMXFGTGVKHV31W9  A3L0DCUXI7X3A9
# 13  3X2YVV51PW3BY3OKMXFGTGVKHV31W9  A2RGIULFG1GWF5
# 14  31JUPBOORP3DY9W6H4HTZF1CXXX8L5  A1160COTUR26JZ
# 15  31JUPBOORP3DY9W6H4HTZF1CXXX8L5  A1UZXOMO6BS6I2
# 16  31JUPBOORP3DY9W6H4HTZF1CXXX8L5  A2BL6ZVUM0B9C8
# 17  3WPCIUYH1C7DYH027LU07YPU21VTDE  A3S67QA0SQVPUJ
# 18  3WPCIUYH1C7DYH027LU07YPU21VTDE  A2BW6WD7LZ9EGV
# 19  3WPCIUYH1C7DYH027LU07YPU21VTDE  A1C2T79XTDHE39
# 20  3A520CCNWPZDBRFTXGE3IBHNEP1EAZ  A1PUHCEBSOWETV
# 21  3A520CCNWPZDBRFTXGE3IBHNEP1EAZ  A3MYTEE8WSEQ2Z
# 22  3A520CCNWPZDBRFTXGE3IBHNEP1EAZ  A1DX0Z20W07YOR
# 23  3ATYLI1PRV1AOBVML0UCGMEK8F4OJY  A2OZF756R5JSG4
# 24  3ATYLI1PRV1AOBVML0UCGMEK8F4OJY  A22ON3MIIG0IJA
# 25  3ATYLI1PRV1AOBVML0UCGMEK8F4OJY  A3JTDNRJYVCGQD

# %%
def compute_statistics(df, data_type, num_questions, ignore_columns):
    average_column_name = 'average-' + data_type
    columns = create_columns_for_data_type(data_type, num_questions)
    selected_columns = [column for column in columns if column not in ignore_columns]
    df[average_column_name] = df[selected_columns].mean(axis=1)
    mean = df[average_column_name].mean()
    std = df[average_column_name].std()
    return mean, std

# %%
score_mean_ctrl, score_std_ctrl = compute_statistics(df_score_ctrl, 'confidence', 4, ['question1-confidence'])
score_mean_expr, score_std_expr = compute_statistics(df_score_expr, 'confidence', 4, ['question1-confidence'])
print('Control group: mean=%f, std=%f' % (score_mean_ctrl, score_std_ctrl))
print('Experimental group: mean=%f, std=%f' % (score_mean_expr, score_std_expr))
# Out:
# Control group: mean=0.505376, std=2.049157
# Experimental group: mean=1.461538, std=1.720664

# %%
acc_mean_ctrl, acc_std_ctrl = compute_statistics(df_accuracy_ctrl, 'answer', 4, ['question1-answer'])
acc_mean_expr, acc_std_expr = compute_statistics(df_accuracy_expr, 'answer', 4, ['question1-answer'])
print('Control group: mean=%f, std=%f' % (acc_mean_ctrl, acc_std_ctrl))
print('Experimental group: mean=%f, std=%f' % (acc_mean_expr, acc_std_expr))
# Out:
# Control group: mean=0.580645, std=0.343918
# Experimental group: mean=0.730769, std=0.266987
