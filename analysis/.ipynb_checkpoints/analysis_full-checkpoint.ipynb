# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.set_option('display.max_columns', 30)

# %%
df_assignments_ctrl = pd.read_csv('../XPlanningEvaluation/resources/mobilerobot/study/prefalign/mturk/assignments/assignments_control_full.csv')
df_assignments_expr = pd.read_csv('../XPlanningEvaluation/resources/mobilerobot/study/prefalign/mturk/assignments/assignments_experimental_full.csv')
df_answers_ctrl = pd.read_csv('../XPlanningEvaluation/resources/mobilerobot/study/prefalign/mturk/assignments/answerKey_control.csv')
df_answers_expr = pd.read_csv('../XPlanningEvaluation/resources/mobilerobot/study/prefalign/mturk/assignments/answerKey_experimental.csv')

# %%
df_assignments_ctrl.head()
# Out:
#    HIT Index                          HIT ID                      HITType ID  \
# 0          0  3BA7SXOG1LPO17RJMOEPLRAB3IOR82  35280GTXAPQ35X4ZWHDC3QI4GWDOVS
# 1          0  3BA7SXOG1LPO17RJMOEPLRAB3IOR82  35280GTXAPQ35X4ZWHDC3QI4GWDOVS
# 2          0  3BA7SXOG1LPO17RJMOEPLRAB3IOR82  35280GTXAPQ35X4ZWHDC3QI4GWDOVS
# 3          0  3BA7SXOG1LPO17RJMOEPLRAB3IOR82  35280GTXAPQ35X4ZWHDC3QI4GWDOVS
# 4          1  3UOMW19E6F518NJY6THRKC1Y1RRC5M  35280GTXAPQ35X4ZWHDC3QI4GWDOVS
#
#                     Assignment ID       Worker ID  Total Time (seconds)  \
# 0  3PWWM24LHVXAK78SX04Q83YSQOR28Y   A7P3R1AIA4TVV                  1106
# 1  3GFK2QRXXCGD95NXDMMUKQ4QS5L5WH  A1SIUJEL2LS8UO                  1164
# 2  35BLDD71I9WY1U7HU0OENSS7MVTVZ6  A272X64FOZFYLB                   722
# 3  3WOKGM4L74F69PSUPUP8M1VD8WUO0O  A1DMXEJGJY02E1                   721
# 4  3P4RDNWND853F9IDD7M9K9ENVWLIJE  A38Z99XF4NDNH0                   471
#
#                question0-ref question0-total-cost question0-answer  \
# 0  question-mission12-agent0                  181              yes
# 1                       null                 null             null
# 2  question-mission12-agent0                  206              yes
# 3  question-mission12-agent0                189.8               no
# 4  question-mission13-agent0                  186               no
#
#   question0-confidence question0-elapsedTime              question1-ref  \
# 0               fairly                 97353  question-mission85-agent0
# 1                 null                  null                       null
# 2               fairly                183265  question-mission85-agent0
# 3           completely                127270  question-mission85-agent0
# 4             slightly                 93320  question-mission95-agent0
#
#   question1-total-cost question1-answer question1-confidence  \
# 0                  108              yes           completely
# 1                 null             null                 null
# 2                  108              yes           completely
# 3                  108              yes           completely
# 4                  138              yes             somewhat
#
#   question1-elapsedTime              question2-ref question2-total-cost  \
# 0                 14373  question-mission26-agent0                  155
# 1                  null                       null                 null
# 2                 60012  question-mission26-agent0                  173
# 3                 36854  question-mission26-agent0                  155
# 4                 25818  question-mission75-agent0                  181
#
#   question2-answer question2-confidence question2-elapsedTime  \
# 0               no           completely                 39149
# 1             null                 null                  null
# 2              yes               fairly                 80461
# 3               no             somewhat                 80468
# 4               no           completely                 35327
#
#                question3-ref  question3-total-cost question3-answer  \
# 0  question-mission74-agent2                 159.0              yes
# 1  question-mission74-agent2                 211.0              yes
# 2  question-mission74-agent2                 199.0              yes
# 3  question-mission74-agent2                 199.0              yes
# 4  question-mission54-agent0                 303.0               no
#
#   question3-confidence  question3-elapsedTime
# 0             somewhat                 146259
# 1             somewhat                  91468
# 2               fairly                  73092
# 3               fairly                  24337
# 4           completely                  62365

# %%
df_assignments_expr.head()
# Out:
#    HIT Index                          HIT ID                      HITType ID  \
# 0          0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ  3K1KXTVNBMKZJI3PCNEA4YMJWSSM1N
# 1          0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ  3K1KXTVNBMKZJI3PCNEA4YMJWSSM1N
# 2          0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ  3K1KXTVNBMKZJI3PCNEA4YMJWSSM1N
# 3          0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ  3K1KXTVNBMKZJI3PCNEA4YMJWSSM1N
# 4          1  3HJ1EVZS2QI20ALDA7JTUA20NXFR3V  3K1KXTVNBMKZJI3PCNEA4YMJWSSM1N
#
#                     Assignment ID       Worker ID  Total Time (seconds)  \
# 0  34FNN24DCP8HYAIXSN4I5NP63IDY5B  A3UF6XXFFRR237                  1018
# 1  31T4R4OBOVFJIBVBKO1Q6GBJR0U7CV  A3D2GO0IFRFN6R                   861
# 2  3D3VGR7TA3E5NUJ709OVIUYPMZER3J   AY7WPVKHVNBLG                  1442
# 3  3TEM0PF1Q8WF5S15ZLBSB7JE4MD0D1    AEWPAZBYA7XE                   885
# 4  3KKG4CDWKLXK1Q6P66TS1EQ1UEK94H  A1F34ZP6YNI98F                   537
#
#                            question0-ref  question0-total-cost  \
# 0  question-mission12-agent0-explanation                 206.0
# 1  question-mission12-agent0-explanation                 206.0
# 2  question-mission12-agent0-explanation                 206.0
# 3  question-mission12-agent0-explanation                 206.0
# 4  question-mission13-agent0-explanation                 393.0
#
#   question0-answer question0-confidence  question0-elapsedTime  \
# 0              yes               fairly                 235538
# 1              yes           completely                 288066
# 2              yes             somewhat                 294507
# 3              yes           completely                 444698
# 4               no               fairly                 129827
#
#                            question1-ref  question1-total-cost  \
# 0  question-mission85-agent0-explanation                    10
# 1  question-mission85-agent0-explanation                   108
# 2  question-mission85-agent0-explanation                   108
# 3  question-mission85-agent0-explanation                   108
# 4  question-mission95-agent0-explanation                   108
#
#   question1-answer question1-confidence  question1-elapsedTime  \
# 0               no           completely                  28398
# 1              yes           completely                  38835
# 2              yes           completely                  43657
# 3              yes           completely                  60877
# 4              yes               fairly                  57762
#
#                            question2-ref  question2-total-cost  \
# 0  question-mission26-agent0-explanation                 173.0
# 1  question-mission26-agent0-explanation                 173.0
# 2  question-mission26-agent0-explanation                 173.0
# 3  question-mission26-agent0-explanation                 173.0
# 4  question-mission75-agent0-explanation                 335.0
#
#   question2-answer question2-confidence  question2-elapsedTime  \
# 0               no           completely                 100612
# 1               no           completely                  82678
# 2              yes             slightly                 124385
# 3               no           completely                  67961
# 4              yes               fairly                 190742
#
#                            question3-ref  question3-total-cost  \
# 0  question-mission74-agent2-explanation                 199.0
# 1  question-mission74-agent2-explanation                 199.0
# 2  question-mission74-agent2-explanation                 199.0
# 3  question-mission74-agent2-explanation                 199.0
# 4  question-mission54-agent0-explanation                 303.0
#
#   question3-answer question3-confidence  question3-elapsedTime
# 0               no           completely                 146051
# 1               no           completely                  69736
# 2               no             somewhat                  98455
# 3               no           completely                  45301
# 4              yes             somewhat                  51402

# %%
df_answers_ctrl.head()
# Out:
#                          ref  total-cost answer
# 0  question-mission59-agent4         708     no
# 1  question-mission80-agent0         108    yes
# 2  question-mission42-agent7         709     no
# 3  question-mission66-agent0         875    yes
# 4  question-mission45-agent7         220     no

# %%
df_answers_expr.head()
# Out:
#                                      ref  total-cost answer
# 0  question-mission12-agent0-explanation         206    yes
# 1  question-mission85-agent0-explanation         108    yes
# 2  question-mission26-agent0-explanation         173    yes
# 3  question-mission74-agent2-explanation         199     no
# 4  question-mission13-agent0-explanation         393    yes

# %%
# Create columns for all data types for all questions
# Columns are named in the format: question[i]-[data_type_name]
def create_columns(data_types, num_questions):
    columns = []
    for i in range(num_questions):
        for data_type in data_types:
            columns.append('question' + str(i) + "-" + data_type)
    return columns

# %%
# Create columns for a single data type for all questions
# Columns are named in the format: question[i]-[data_type_name]
def create_columns_for_data_type(data_type, num_questions):
    return ['question' + str(i) + '-' + data_type for i in range(num_questions)]

# %%
# Remove any assignment (i.e., any row) that contains missing data of a given data type of any question
def remove_assignments_with_missing_data(df_assignments, data_type, num_questions):
    columns = create_columns_for_data_type(data_type, num_questions)
    non_numeric_df_assignments_columns = df_assignments.select_dtypes(exclude=['int','float']).columns
    non_numeric_columns = [column for column in columns if column in non_numeric_df_assignments_columns]
    for column in non_numeric_columns:
        df_assignments = df_assignments[df_assignments[column] != 'null']
    return df_assignments

# %%
def set_columns_type_to_numeric(df_assignments, data_type, num_questions):
    columns = create_columns_for_data_type(data_type, num_questions)
    df_assignments[columns] = df_assignments[columns].apply(pd.to_numeric)
    return df_assignments

# %%
df_assignments_ctrl = remove_assignments_with_missing_data(df_assignments_ctrl, 'total-cost', 4)
df_assignments_ctrl.head()
# Out:
#    HIT Index                          HIT ID                      HITType ID  \
# 0          0  3BA7SXOG1LPO17RJMOEPLRAB3IOR82  35280GTXAPQ35X4ZWHDC3QI4GWDOVS
# 2          0  3BA7SXOG1LPO17RJMOEPLRAB3IOR82  35280GTXAPQ35X4ZWHDC3QI4GWDOVS
# 3          0  3BA7SXOG1LPO17RJMOEPLRAB3IOR82  35280GTXAPQ35X4ZWHDC3QI4GWDOVS
# 4          1  3UOMW19E6F518NJY6THRKC1Y1RRC5M  35280GTXAPQ35X4ZWHDC3QI4GWDOVS
# 5          1  3UOMW19E6F518NJY6THRKC1Y1RRC5M  35280GTXAPQ35X4ZWHDC3QI4GWDOVS
#
#                     Assignment ID       Worker ID  Total Time (seconds)  \
# 0  3PWWM24LHVXAK78SX04Q83YSQOR28Y   A7P3R1AIA4TVV                  1106
# 2  35BLDD71I9WY1U7HU0OENSS7MVTVZ6  A272X64FOZFYLB                   722
# 3  3WOKGM4L74F69PSUPUP8M1VD8WUO0O  A1DMXEJGJY02E1                   721
# 4  3P4RDNWND853F9IDD7M9K9ENVWLIJE  A38Z99XF4NDNH0                   471
# 5  3HRMW88U19PI9M7ICEAVUX68DWYM0Q  A1K5ILJMG439M5                  1051
#
#                question0-ref question0-total-cost question0-answer  \
# 0  question-mission12-agent0                  181              yes
# 2  question-mission12-agent0                  206              yes
# 3  question-mission12-agent0                189.8               no
# 4  question-mission13-agent0                  186               no
# 5  question-mission13-agent0                  393              yes
#
#   question0-confidence question0-elapsedTime              question1-ref  \
# 0               fairly                 97353  question-mission85-agent0
# 2               fairly                183265  question-mission85-agent0
# 3           completely                127270  question-mission85-agent0
# 4             slightly                 93320  question-mission95-agent0
# 5             somewhat                260413  question-mission95-agent0
#
#   question1-total-cost question1-answer question1-confidence  \
# 0                  108              yes           completely
# 2                  108              yes           completely
# 3                  108              yes           completely
# 4                  138              yes             somewhat
# 5                  108              yes               fairly
#
#   question1-elapsedTime              question2-ref question2-total-cost  \
# 0                 14373  question-mission26-agent0                  155
# 2                 60012  question-mission26-agent0                  173
# 3                 36854  question-mission26-agent0                  155
# 4                 25818  question-mission75-agent0                  181
# 5                 61612  question-mission75-agent0                  335
#
#   question2-answer question2-confidence question2-elapsedTime  \
# 0               no           completely                 39149
# 2              yes               fairly                 80461
# 3               no             somewhat                 80468
# 4               no           completely                 35327
# 5              yes             somewhat                139476
#
#                question3-ref  question3-total-cost question3-answer  \
# 0  question-mission74-agent2                 159.0              yes
# 2  question-mission74-agent2                 199.0              yes
# 3  question-mission74-agent2                 199.0              yes
# 4  question-mission54-agent0                 303.0               no
# 5  question-mission54-agent0                 303.0               no
#
#   question3-confidence  question3-elapsedTime
# 0             somewhat                 146259
# 2               fairly                  73092
# 3               fairly                  24337
# 4           completely                  62365
# 5             slightly                  90964

# %%
df_assignments_expr = remove_assignments_with_missing_data(df_assignments_expr, 'total-cost', 4)
df_assignments_expr.head()
# Out:
#    HIT Index                          HIT ID                      HITType ID  \
# 0          0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ  3K1KXTVNBMKZJI3PCNEA4YMJWSSM1N
# 1          0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ  3K1KXTVNBMKZJI3PCNEA4YMJWSSM1N
# 2          0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ  3K1KXTVNBMKZJI3PCNEA4YMJWSSM1N
# 3          0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ  3K1KXTVNBMKZJI3PCNEA4YMJWSSM1N
# 4          1  3HJ1EVZS2QI20ALDA7JTUA20NXFR3V  3K1KXTVNBMKZJI3PCNEA4YMJWSSM1N
#
#                     Assignment ID       Worker ID  Total Time (seconds)  \
# 0  34FNN24DCP8HYAIXSN4I5NP63IDY5B  A3UF6XXFFRR237                  1018
# 1  31T4R4OBOVFJIBVBKO1Q6GBJR0U7CV  A3D2GO0IFRFN6R                   861
# 2  3D3VGR7TA3E5NUJ709OVIUYPMZER3J   AY7WPVKHVNBLG                  1442
# 3  3TEM0PF1Q8WF5S15ZLBSB7JE4MD0D1    AEWPAZBYA7XE                   885
# 4  3KKG4CDWKLXK1Q6P66TS1EQ1UEK94H  A1F34ZP6YNI98F                   537
#
#                            question0-ref  question0-total-cost  \
# 0  question-mission12-agent0-explanation                 206.0
# 1  question-mission12-agent0-explanation                 206.0
# 2  question-mission12-agent0-explanation                 206.0
# 3  question-mission12-agent0-explanation                 206.0
# 4  question-mission13-agent0-explanation                 393.0
#
#   question0-answer question0-confidence  question0-elapsedTime  \
# 0              yes               fairly                 235538
# 1              yes           completely                 288066
# 2              yes             somewhat                 294507
# 3              yes           completely                 444698
# 4               no               fairly                 129827
#
#                            question1-ref  question1-total-cost  \
# 0  question-mission85-agent0-explanation                    10
# 1  question-mission85-agent0-explanation                   108
# 2  question-mission85-agent0-explanation                   108
# 3  question-mission85-agent0-explanation                   108
# 4  question-mission95-agent0-explanation                   108
#
#   question1-answer question1-confidence  question1-elapsedTime  \
# 0               no           completely                  28398
# 1              yes           completely                  38835
# 2              yes           completely                  43657
# 3              yes           completely                  60877
# 4              yes               fairly                  57762
#
#                            question2-ref  question2-total-cost  \
# 0  question-mission26-agent0-explanation                 173.0
# 1  question-mission26-agent0-explanation                 173.0
# 2  question-mission26-agent0-explanation                 173.0
# 3  question-mission26-agent0-explanation                 173.0
# 4  question-mission75-agent0-explanation                 335.0
#
#   question2-answer question2-confidence  question2-elapsedTime  \
# 0               no           completely                 100612
# 1               no           completely                  82678
# 2              yes             slightly                 124385
# 3               no           completely                  67961
# 4              yes               fairly                 190742
#
#                            question3-ref  question3-total-cost  \
# 0  question-mission74-agent2-explanation                 199.0
# 1  question-mission74-agent2-explanation                 199.0
# 2  question-mission74-agent2-explanation                 199.0
# 3  question-mission74-agent2-explanation                 199.0
# 4  question-mission54-agent0-explanation                 303.0
#
#   question3-answer question3-confidence  question3-elapsedTime
# 0               no           completely                 146051
# 1               no           completely                  69736
# 2               no             somewhat                  98455
# 3               no           completely                  45301
# 4              yes             somewhat                  51402

# %%
# Compute accuracy of total-cost (in %error) and answer (correct/incorrect) for each question, from each worker
def compute_accuracy(df_assignments, df_answers):
    # Accuracy of total-cost (%error) and answer (correct/incorrect) from workers
    accuracy_columns = create_columns(['ref', 'total-cost', 'answer'], 4)
    df_accuracy = pd.DataFrame(columns=accuracy_columns)
    
    # Data columns of interest for each question: ref, total-cost, answer
    ref_columns = create_columns_for_data_type('ref', 4)
    total_cost_columns = create_columns_for_data_type('total-cost', 4)
    answer_columns = create_columns_for_data_type('answer', 4)
    
    df_assignments = set_columns_type_to_numeric(df_assignments, 'total-cost', 4)
    
    for index, row in df_assignments.iterrows():
        # ref: question-mission[i]-agent[j] is shared between assignments and answerKey tables
        df_answer_key = df_answers[df_answers.ref.isin(row[ref_columns])]

        # Accuracy of total-cost and answer from workers
        worker_acc_dict = {'HIT ID': row['HIT ID'], 'Worker ID': row['Worker ID']}

        for i in range(4):
            ref_column = ref_columns[i] # question[i]-ref
            total_cost_column = total_cost_columns[i] # question[i]-total-cost
            answer_column = answer_columns[i] # question[i]-answer

            # total-cost and %error
            worker_total_cost = row[total_cost_column]
            correct_total_cost = df_answer_key[df_answer_key.ref == row[ref_column]].iloc[0]['total-cost']
            total_cost_err = abs((correct_total_cost - worker_total_cost) / correct_total_cost)

            # answer and correct/incorrect
            worker_answer = row[answer_column]
            correct_answer = df_answer_key[df_answer_key.ref == row[ref_column]].iloc[0]['answer']
            answer_acc = 1 if worker_answer == correct_answer else 0

            # Accuracy dict
            worker_acc_dict[ref_column] = row[ref_column]
            worker_acc_dict[total_cost_column] = total_cost_err
            worker_acc_dict[answer_column] = answer_acc

        df_accuracy = df_accuracy.append(worker_acc_dict, ignore_index=True)
    return df_accuracy

# %%
df_accuracy_ctrl = compute_accuracy(df_assignments_ctrl, df_answers_ctrl)
df_accuracy_ctrl.head()
# Out:
#                question0-ref  question0-total-cost  question0-answer  \
# 0  question-mission12-agent0              0.121359               1.0
# 1  question-mission12-agent0              0.000000               1.0
# 2  question-mission12-agent0              0.078641               0.0
# 3  question-mission13-agent0              0.526718               0.0
# 4  question-mission13-agent0              0.000000               1.0
#
#                question1-ref  question1-total-cost  question1-answer  \
# 0  question-mission85-agent0              0.000000               1.0
# 1  question-mission85-agent0              0.000000               1.0
# 2  question-mission85-agent0              0.000000               1.0
# 3  question-mission95-agent0              0.277778               1.0
# 4  question-mission95-agent0              0.000000               1.0
#
#                question2-ref  question2-total-cost  question2-answer  \
# 0  question-mission26-agent0              0.104046               0.0
# 1  question-mission26-agent0              0.000000               1.0
# 2  question-mission26-agent0              0.104046               0.0
# 3  question-mission75-agent0              0.459701               0.0
# 4  question-mission75-agent0              0.000000               1.0
#
#                question3-ref  question3-total-cost  question3-answer  \
# 0  question-mission74-agent2              0.201005               0.0
# 1  question-mission74-agent2              0.000000               0.0
# 2  question-mission74-agent2              0.000000               0.0
# 3  question-mission54-agent0              0.000000               0.0
# 4  question-mission54-agent0              0.000000               0.0
#
#                            HIT ID       Worker ID
# 0  3BA7SXOG1LPO17RJMOEPLRAB3IOR82   A7P3R1AIA4TVV
# 1  3BA7SXOG1LPO17RJMOEPLRAB3IOR82  A272X64FOZFYLB
# 2  3BA7SXOG1LPO17RJMOEPLRAB3IOR82  A1DMXEJGJY02E1
# 3  3UOMW19E6F518NJY6THRKC1Y1RRC5M  A38Z99XF4NDNH0
# 4  3UOMW19E6F518NJY6THRKC1Y1RRC5M  A1K5ILJMG439M5

# %%
df_accuracy_expr = compute_accuracy(df_assignments_expr, df_answers_expr)
df_accuracy_expr.head()
# Out:
#                            question0-ref  question0-total-cost  \
# 0  question-mission12-agent0-explanation                   0.0
# 1  question-mission12-agent0-explanation                   0.0
# 2  question-mission12-agent0-explanation                   0.0
# 3  question-mission12-agent0-explanation                   0.0
# 4  question-mission13-agent0-explanation                   0.0
#
#    question0-answer                          question1-ref  \
# 0               1.0  question-mission85-agent0-explanation
# 1               1.0  question-mission85-agent0-explanation
# 2               1.0  question-mission85-agent0-explanation
# 3               1.0  question-mission85-agent0-explanation
# 4               0.0  question-mission95-agent0-explanation
#
#    question1-total-cost  question1-answer  \
# 0              0.907407               0.0
# 1              0.000000               1.0
# 2              0.000000               1.0
# 3              0.000000               1.0
# 4              0.000000               1.0
#
#                            question2-ref  question2-total-cost  \
# 0  question-mission26-agent0-explanation                   0.0
# 1  question-mission26-agent0-explanation                   0.0
# 2  question-mission26-agent0-explanation                   0.0
# 3  question-mission26-agent0-explanation                   0.0
# 4  question-mission75-agent0-explanation                   0.0
#
#    question2-answer                          question3-ref  \
# 0               0.0  question-mission74-agent2-explanation
# 1               0.0  question-mission74-agent2-explanation
# 2               1.0  question-mission74-agent2-explanation
# 3               0.0  question-mission74-agent2-explanation
# 4               1.0  question-mission54-agent0-explanation
#
#    question3-total-cost  question3-answer                          HIT ID  \
# 0                   0.0               1.0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ
# 1                   0.0               1.0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ
# 2                   0.0               1.0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ
# 3                   0.0               1.0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ
# 4                   0.0               1.0  3HJ1EVZS2QI20ALDA7JTUA20NXFR3V
#
#         Worker ID
# 0  A3UF6XXFFRR237
# 1  A3D2GO0IFRFN6R
# 2   AY7WPVKHVNBLG
# 3    AEWPAZBYA7XE
# 4  A1F34ZP6YNI98F

# %%
def compute_score(df_assignments, df_answers):
    # Score of answer-confidence combination
    score_columns = create_columns(['ref', 'confidence'], 4)
    df_score = pd.DataFrame(columns=score_columns)

    confidence_abs_scores = {'none': 0, 'slightly': 1, 'somewhat': 2, 'fairly': 3, 'completely': 4}
    
    # Data columns of interest for each question: ref, answer, confidence
    ref_columns = create_columns_for_data_type('ref', 4)
    answer_columns = create_columns_for_data_type('answer', 4)
    confidence_columns = create_columns_for_data_type('confidence', 4)

    for index, row in df_assignments.iterrows():
        # ref: question-mission[i]-agent[j] is shared between assignments and answerKey tables
        df_answer_key = df_answers[df_answers.ref.isin(row[ref_columns])]

        # Score of answer-confidence combination
        worker_score_dict = {'HIT ID': row['HIT ID'], 'Worker ID': row['Worker ID']}

        for i in range(4):
            ref_column = ref_columns[i] # question[i]-ref
            answer_column = answer_columns[i] # question[i]-answer
            confidence_column = confidence_columns[i] # question[i]-confidence

            # answer and correct/incorrect
            worker_answer = row[answer_column]
            correct_answer = df_answer_key[df_answer_key.ref == row[ref_column]].iloc[0]['answer']
            answer_acc = worker_answer == correct_answer

            # confidence and score
            worker_confidence = row[confidence_column]
            score = confidence_abs_scores[worker_confidence] if answer_acc else -1 * confidence_abs_scores[worker_confidence]

            # Score dict
            worker_score_dict[ref_column] = row[ref_column]
            worker_score_dict[confidence_column] = score

        df_score = df_score.append(worker_score_dict, ignore_index=True)
    return df_score

# %%
df_score_ctrl = compute_score(df_assignments_ctrl, df_answers_ctrl)
df_score_ctrl.head()
# Out:
#                question0-ref  question0-confidence              question1-ref  \
# 0  question-mission12-agent0                   3.0  question-mission85-agent0
# 1  question-mission12-agent0                   3.0  question-mission85-agent0
# 2  question-mission12-agent0                  -4.0  question-mission85-agent0
# 3  question-mission13-agent0                  -1.0  question-mission95-agent0
# 4  question-mission13-agent0                   2.0  question-mission95-agent0
#
#    question1-confidence              question2-ref  question2-confidence  \
# 0                   4.0  question-mission26-agent0                  -4.0
# 1                   4.0  question-mission26-agent0                   3.0
# 2                   4.0  question-mission26-agent0                  -2.0
# 3                   2.0  question-mission75-agent0                  -4.0
# 4                   3.0  question-mission75-agent0                   2.0
#
#                question3-ref  question3-confidence  \
# 0  question-mission74-agent2                  -2.0
# 1  question-mission74-agent2                  -3.0
# 2  question-mission74-agent2                  -3.0
# 3  question-mission54-agent0                  -4.0
# 4  question-mission54-agent0                  -1.0
#
#                            HIT ID       Worker ID
# 0  3BA7SXOG1LPO17RJMOEPLRAB3IOR82   A7P3R1AIA4TVV
# 1  3BA7SXOG1LPO17RJMOEPLRAB3IOR82  A272X64FOZFYLB
# 2  3BA7SXOG1LPO17RJMOEPLRAB3IOR82  A1DMXEJGJY02E1
# 3  3UOMW19E6F518NJY6THRKC1Y1RRC5M  A38Z99XF4NDNH0
# 4  3UOMW19E6F518NJY6THRKC1Y1RRC5M  A1K5ILJMG439M5

# %%
df_score_expr = compute_score(df_assignments_expr, df_answers_expr)
df_score_expr.head()
# Out:
#                            question0-ref  question0-confidence  \
# 0  question-mission12-agent0-explanation                   3.0
# 1  question-mission12-agent0-explanation                   4.0
# 2  question-mission12-agent0-explanation                   2.0
# 3  question-mission12-agent0-explanation                   4.0
# 4  question-mission13-agent0-explanation                  -3.0
#
#                            question1-ref  question1-confidence  \
# 0  question-mission85-agent0-explanation                  -4.0
# 1  question-mission85-agent0-explanation                   4.0
# 2  question-mission85-agent0-explanation                   4.0
# 3  question-mission85-agent0-explanation                   4.0
# 4  question-mission95-agent0-explanation                   3.0
#
#                            question2-ref  question2-confidence  \
# 0  question-mission26-agent0-explanation                  -4.0
# 1  question-mission26-agent0-explanation                  -4.0
# 2  question-mission26-agent0-explanation                   1.0
# 3  question-mission26-agent0-explanation                  -4.0
# 4  question-mission75-agent0-explanation                   3.0
#
#                            question3-ref  question3-confidence  \
# 0  question-mission74-agent2-explanation                   4.0
# 1  question-mission74-agent2-explanation                   4.0
# 2  question-mission74-agent2-explanation                   2.0
# 3  question-mission74-agent2-explanation                   4.0
# 4  question-mission54-agent0-explanation                   2.0
#
#                            HIT ID       Worker ID
# 0  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ  A3UF6XXFFRR237
# 1  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ  A3D2GO0IFRFN6R
# 2  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ   AY7WPVKHVNBLG
# 3  3RWO3EJELJ8LEURJAB1L1MNOOVB1PJ    AEWPAZBYA7XE
# 4  3HJ1EVZS2QI20ALDA7JTUA20NXFR3V  A1F34ZP6YNI98F

# %%
def compute_statistics(df, data_type, num_questions, ignore_columns):
    average_column_name = 'average-' + data_type
    columns = create_columns_for_data_type(data_type, num_questions)
    selected_columns = [column for column in columns if column not in ignore_columns]
    df[average_column_name] = df[selected_columns].mean(axis=1)
    mean = df[average_column_name].mean()
    std = df[average_column_name].std()
    return mean, std, df[average_column_name]

# %%
score_mean_ctrl, score_std_ctrl, scores_ctrl = compute_statistics(df_score_ctrl, 'confidence', 4, ['question1-confidence'])
score_mean_expr, score_std_expr, scores_expr = compute_statistics(df_score_expr, 'confidence', 4, ['question1-confidence'])
print('Score statistics:')
print('Control group: mean=%f, std=%f' % (score_mean_ctrl, score_std_ctrl))
print('Experimental group: mean=%f, std=%f' % (score_mean_expr, score_std_expr))
# Out:
# Score statistics:
# Control group: mean=0.346939, std=2.038926
# Experimental group: mean=2.066667, std=1.711638

# %%
df_scores = pd.DataFrame({'scores_ctrl': scores_ctrl, 'scores_expr': scores_expr})
ax_scores = df_scores.plot.kde()

# %%
axhist_scores = df_scores.plot.hist(bins=20, alpha=0.3)

# %%
acc_mean_ctrl, acc_std_ctrl, accs_ctrl = compute_statistics(df_accuracy_ctrl, 'answer', 4, ['question1-answer'])
acc_mean_expr, acc_std_expr, accs_expr = compute_statistics(df_accuracy_expr, 'answer', 4, ['question1-answer'])
print('Accuracy statistics:')
print('Control group: mean=%f, std=%f' % (acc_mean_ctrl, acc_std_ctrl))
print('Experimental group: mean=%f, std=%f' % (acc_mean_expr, acc_std_expr))
# Out:
# Accuracy statistics:
# Control group: mean=0.557823, std=0.329054
# Experimental group: mean=0.800000, std=0.233285

# %%
df_accs = pd.DataFrame({'accs_ctrl': accs_ctrl, 'accs_expr': accs_expr})
ax_accs = df_accs.plot.kde()

# %%
axhist_accs = df_accs.plot.hist(bins=20, alpha=0.3)

# %%
def filter_columns(columns, ignore_columns):
    return [column for column in columns if column not in ignore_columns]

# %%
def create_mixed_effect_table(df_accuracy, df_score, ignore_columns):
    mixed_effect_columns = ['question-ref', 'group', 'participant', 'accuracy', 'score']
    df_mixed_effect = pd.DataFrame(columns=mixed_effect_columns)
    
    ref_columns = create_columns_for_data_type('ref', 4) # question[i]-ref
    answer_columns = create_columns_for_data_type('answer', 4) # question[i]-answer (accuracy)
    confidence_columns = create_columns_for_data_type('confidence', 4) # question[i]-confidence (accuracy-confidence score)
    
    # Filter out some columns (e.g., data from validation question)
    selected_ref_columns = filter_columns(ref_columns, ignore_columns)
    selected_answer_columns = filter_columns(answer_columns, ignore_columns)
    selected_confidence_columns = filter_columns(confidence_columns, ignore_columns)
    
    worker_column = ['Worker ID']
    selected_df_accuracy = df_accuracy[selected_ref_columns + selected_answer_columns + worker_column]
    selected_df_score = df_score[selected_ref_columns + selected_confidence_columns + worker_column]
    
    for i in range(selected_df_accuracy.shape[0]):
        row_accuracy = selected_df_accuracy.iloc[i]
        row_score = selected_df_score.iloc[i]
        participant = row_accuracy.get('Worker ID')
        for i in range(4):
            if ref_columns[i] in ignore_columns:
                continue
            ref = row_accuracy.get(ref_columns[i])
            group = 'experimental' if '-explanation' in ref else 'control'
            accuracy = row_accuracy.get(answer_columns[i])
            score = row_score.get(confidence_columns[i])
            
            ref_modified = ref.replace('-explanation', '')
            row_dict = {'question-ref': ref_modified, 'group': group, 'participant': participant, 'accuracy': accuracy, 'score': score}
            df_mixed_effect = df_mixed_effect.append(row_dict, ignore_index=True)
    
    return df_mixed_effect

# %%
df_mixed_effect_ctrl = create_mixed_effect_table(df_accuracy_ctrl, df_score_ctrl, [])
df_mixed_effect_expr = create_mixed_effect_table(df_accuracy_expr, df_score_expr, [])

# %%
df_mixed_effect_ctrl.head()
# Out:
#                 question-ref    group     participant  accuracy  score
# 0  question-mission12-agent0  control   A7P3R1AIA4TVV       1.0    3.0
# 1  question-mission85-agent0  control   A7P3R1AIA4TVV       1.0    4.0
# 2  question-mission26-agent0  control   A7P3R1AIA4TVV       0.0   -4.0
# 3  question-mission74-agent2  control   A7P3R1AIA4TVV       0.0   -2.0
# 4  question-mission12-agent0  control  A272X64FOZFYLB       1.0    3.0

# %%
df_mixed_effect_expr.head()
# Out:
#                 question-ref         group     participant  accuracy  score
# 0  question-mission12-agent0  experimental  A3UF6XXFFRR237       1.0    3.0
# 1  question-mission85-agent0  experimental  A3UF6XXFFRR237       0.0   -4.0
# 2  question-mission26-agent0  experimental  A3UF6XXFFRR237       0.0   -4.0
# 3  question-mission74-agent2  experimental  A3UF6XXFFRR237       1.0    4.0
# 4  question-mission12-agent0  experimental  A3D2GO0IFRFN6R       1.0    4.0

# %%
df_mixed_effect_all = df_mixed_effect_ctrl.append(df_mixed_effect_expr, ignore_index=True)

# %%
df_mixed_effect_all.head()
# Out:
#                 question-ref    group     participant  accuracy  score
# 0  question-mission12-agent0  control   A7P3R1AIA4TVV       1.0    3.0
# 1  question-mission85-agent0  control   A7P3R1AIA4TVV       1.0    4.0
# 2  question-mission26-agent0  control   A7P3R1AIA4TVV       0.0   -4.0
# 3  question-mission74-agent2  control   A7P3R1AIA4TVV       0.0   -2.0
# 4  question-mission12-agent0  control  A272X64FOZFYLB       1.0    3.0

# %%
# df_mixed_effect_all.to_csv('data_all.csv', encoding='utf-8', index=False)

# %%
ignore_columns_validation = ['question1-ref', 'question1-answer', 'question1-confidence']
df_mixed_effect_3qs_ctrl = create_mixed_effect_table(df_accuracy_ctrl, df_score_ctrl, ignore_columns_validation)
df_mixed_effect_3qs_expr = create_mixed_effect_table(df_accuracy_expr, df_score_expr, ignore_columns_validation)

# %%
df_mixed_effect_3qs_ctrl.head()
# Out:
#                 question-ref    group     participant  accuracy  score
# 0  question-mission12-agent0  control   A7P3R1AIA4TVV       1.0    3.0
# 1  question-mission26-agent0  control   A7P3R1AIA4TVV       0.0   -4.0
# 2  question-mission74-agent2  control   A7P3R1AIA4TVV       0.0   -2.0
# 3  question-mission12-agent0  control  A272X64FOZFYLB       1.0    3.0
# 4  question-mission26-agent0  control  A272X64FOZFYLB       1.0    3.0

# %%
df_mixed_effect_3qs_expr.head()
# Out:
#                 question-ref         group     participant  accuracy  score
# 0  question-mission12-agent0  experimental  A3UF6XXFFRR237       1.0    3.0
# 1  question-mission26-agent0  experimental  A3UF6XXFFRR237       0.0   -4.0
# 2  question-mission74-agent2  experimental  A3UF6XXFFRR237       1.0    4.0
# 3  question-mission12-agent0  experimental  A3D2GO0IFRFN6R       1.0    4.0
# 4  question-mission26-agent0  experimental  A3D2GO0IFRFN6R       0.0   -4.0

# %%
df_mixed_effect_3qs_all = df_mixed_effect_3qs_ctrl.append(df_mixed_effect_3qs_expr, ignore_index=True)

# %%
df_mixed_effect_3qs_all.head()
# Out:
#                 question-ref    group     participant  accuracy  score
# 0  question-mission12-agent0  control   A7P3R1AIA4TVV       1.0    3.0
# 1  question-mission26-agent0  control   A7P3R1AIA4TVV       0.0   -4.0
# 2  question-mission74-agent2  control   A7P3R1AIA4TVV       0.0   -2.0
# 3  question-mission12-agent0  control  A272X64FOZFYLB       1.0    3.0
# 4  question-mission26-agent0  control  A272X64FOZFYLB       1.0    3.0

# %%
# df_mixed_effect_3qs_all.to_csv('data_3qs.csv', encoding='utf-8', index=False)

# %%
df_questions_acc_ctrl = df_mixed_effect_3qs_ctrl.groupby(['question-ref'], as_index=False).mean().sort_values('accuracy')
df_questions_acc_expr = df_mixed_effect_3qs_expr.groupby(['question-ref'], as_index=False).mean().sort_values('accuracy')

# %%
df_questions_acc_ctrl
# Out:
#                  question-ref  accuracy     score
# 23  question-mission46-agent7  0.000000 -2.666667
# 44  question-mission78-agent2  0.000000 -3.000000
# 42  question-mission74-agent2  0.000000 -2.666667
# 38  question-mission67-agent2  0.000000 -3.333333
# 35  question-mission64-agent1  0.000000 -2.333333
# 33   question-mission6-agent1  0.000000 -2.333333
# 27  question-mission52-agent7  0.000000 -3.000000
# 9   question-mission25-agent2  0.000000 -3.000000
# 47   question-mission9-agent1  0.000000 -2.666667
# 28  question-mission54-agent0  0.333333 -0.333333
# 31  question-mission58-agent4  0.333333 -0.666667
# 36  question-mission65-agent2  0.333333 -0.666667
# 25  question-mission48-agent6  0.333333 -1.333333
# 39  question-mission68-agent0  0.333333 -1.333333
# 11   question-mission3-agent3  0.333333 -2.000000
# 10  question-mission26-agent0  0.333333 -1.000000
# 13  question-mission32-agent0  0.333333 -0.333333
# 6   question-mission20-agent3  0.333333 -1.333333
# 43  question-mission75-agent0  0.666667  0.000000
# 2   question-mission12-agent0  0.666667  0.666667
# 40  question-mission69-agent0  0.666667  1.333333
# 1   question-mission11-agent0  0.666667  1.000000
# 3   question-mission13-agent0  0.666667  1.000000
# 4   question-mission14-agent0  0.666667  1.666667
# 5   question-mission15-agent0  0.666667  1.666667
# 32  question-mission59-agent4  0.666667  1.000000
# 30  question-mission57-agent0  0.666667  1.000000
# 7   question-mission23-agent0  0.666667  1.333333
# 14  question-mission34-agent1  0.666667 -0.333333
# 24  question-mission47-agent6  0.666667  0.000000
# 16  question-mission36-agent6  0.666667  2.000000
# 22  question-mission45-agent7  0.666667  1.000000
# 18  question-mission41-agent0  0.666667  1.000000
# 20  question-mission43-agent0  0.666667  0.666667
# 26   question-mission5-agent0  0.666667  0.666667
# 8   question-mission24-agent0  0.750000  1.750000
# 17  question-mission37-agent0  0.750000  2.250000
# 0   question-mission10-agent0  0.750000  1.750000
# 34  question-mission63-agent8  1.000000  2.333333
# 21  question-mission44-agent6  1.000000  2.000000
# 46   question-mission8-agent0  1.000000  3.666667
# 41   question-mission7-agent0  1.000000  3.333333
# 15  question-mission35-agent0  1.000000  2.333333
# 29  question-mission56-agent0  1.000000  2.666667
# 12  question-mission31-agent6  1.000000  3.000000
# 45  question-mission79-agent0  1.000000  3.000000
# 19  question-mission42-agent7  1.000000  2.666667
# 37  question-mission66-agent0  1.000000  2.666667

# %%
df_questions_acc_expr
# Out:
#                  question-ref  accuracy     score
# 3   question-mission13-agent0  0.000000 -2.000000
# 12  question-mission31-agent6  0.000000 -3.000000
# 10  question-mission26-agent0  0.250000 -2.750000
# 27  question-mission52-agent7  0.333333 -1.333333
# 38  question-mission67-agent2  0.333333 -0.333333
# 18  question-mission41-agent0  0.333333 -0.666667
# 21  question-mission44-agent6  0.333333 -1.333333
# 9   question-mission25-agent2  0.333333 -0.666667
# 24  question-mission47-agent6  0.666667  1.000000
# 25  question-mission48-agent6  0.666667  1.333333
# 14  question-mission34-agent1  0.666667  1.000000
# 15  question-mission35-agent0  0.666667  1.666667
# 7   question-mission23-agent0  0.666667  1.333333
# 6   question-mission20-agent3  0.666667  1.000000
# 5   question-mission15-agent0  0.666667  1.666667
# 1   question-mission11-agent0  0.666667  0.000000
# 43  question-mission75-agent0  0.666667  1.666667
# 22  question-mission45-agent7  0.666667  1.000000
# 17  question-mission37-agent0  0.750000  1.500000
# 36  question-mission65-agent2  1.000000  2.666667
# 35  question-mission64-agent1  1.000000  4.000000
# 34  question-mission63-agent8  1.000000  3.666667
# 37  question-mission66-agent0  1.000000  3.333333
# 0   question-mission10-agent0  1.000000  2.250000
# 40  question-mission69-agent0  1.000000  3.666667
# 33   question-mission6-agent1  1.000000  4.000000
# 41   question-mission7-agent0  1.000000  4.000000
# 42  question-mission74-agent2  1.000000  3.500000
# 44  question-mission78-agent2  1.000000  4.000000
# 45  question-mission79-agent0  1.000000  3.666667
# 39  question-mission68-agent0  1.000000  3.666667
# 32  question-mission59-agent4  1.000000  3.333333
# 23  question-mission46-agent7  1.000000  4.000000
# 30  question-mission57-agent0  1.000000  3.333333
# 29  question-mission56-agent0  1.000000  3.666667
# 28  question-mission54-agent0  1.000000  1.666667
# 26   question-mission5-agent0  1.000000  3.333333
# 46   question-mission8-agent0  1.000000  3.666667
# 20  question-mission43-agent0  1.000000  3.333333
# 19  question-mission42-agent7  1.000000  3.666667
# 16  question-mission36-agent6  1.000000  4.000000
# 13  question-mission32-agent0  1.000000  4.000000
# 11   question-mission3-agent3  1.000000  3.666667
# 8   question-mission24-agent0  1.000000  2.250000
# 4   question-mission14-agent0  1.000000  3.000000
# 2   question-mission12-agent0  1.000000  3.250000
# 31  question-mission58-agent4  1.000000  2.333333
# 47   question-mission9-agent1  1.000000  4.000000

# %%
ax_questions_acc_ctr = df_questions_acc_ctrl.plot.bar(x='question-ref', y='accuracy')

# %%
ax_questions_acc_expr = df_questions_acc_expr.plot.bar(x='question-ref', y='accuracy')

# %%
df_questions_acc_expr_reindexed = df_questions_acc_expr.set_index('question-ref')
df_questions_acc_expr_reindexed = df_questions_acc_expr_reindexed.reindex(index=df_questions_acc_ctrl['question-ref'])
df_questions_acc_expr_reindexed = df_questions_acc_expr_reindexed.reset_index()

# %%
ls_questions_acc_ctrl = df_questions_acc_ctrl['accuracy'].tolist()
ls_questions_acc_expr = df_questions_acc_expr_reindexed['accuracy'].tolist()

# %%
questions_order = df_questions_acc_ctrl['question-ref'].tolist()
df_questions_acc_all = pd.DataFrame({'control': ls_questions_acc_ctrl, 'experimental': ls_questions_acc_expr}, index=questions_order)

# %%
df_questions_acc_all
# Out:
#                             control  experimental
# question-mission46-agent7  0.000000      1.000000
# question-mission78-agent2  0.000000      1.000000
# question-mission74-agent2  0.000000      1.000000
# question-mission67-agent2  0.000000      0.333333
# question-mission64-agent1  0.000000      1.000000
# question-mission6-agent1   0.000000      1.000000
# question-mission52-agent7  0.000000      0.333333
# question-mission25-agent2  0.000000      0.333333
# question-mission9-agent1   0.000000      1.000000
# question-mission54-agent0  0.333333      1.000000
# question-mission58-agent4  0.333333      1.000000
# question-mission65-agent2  0.333333      1.000000
# question-mission48-agent6  0.333333      0.666667
# question-mission68-agent0  0.333333      1.000000
# question-mission3-agent3   0.333333      1.000000
# question-mission26-agent0  0.333333      0.250000
# question-mission32-agent0  0.333333      1.000000
# question-mission20-agent3  0.333333      0.666667
# question-mission75-agent0  0.666667      0.666667
# question-mission12-agent0  0.666667      1.000000
# question-mission69-agent0  0.666667      1.000000
# question-mission11-agent0  0.666667      0.666667
# question-mission13-agent0  0.666667      0.000000
# question-mission14-agent0  0.666667      1.000000
# question-mission15-agent0  0.666667      0.666667
# question-mission59-agent4  0.666667      1.000000
# question-mission57-agent0  0.666667      1.000000
# question-mission23-agent0  0.666667      0.666667
# question-mission34-agent1  0.666667      0.666667
# question-mission47-agent6  0.666667      0.666667
# question-mission36-agent6  0.666667      1.000000
# question-mission45-agent7  0.666667      0.666667
# question-mission41-agent0  0.666667      0.333333
# question-mission43-agent0  0.666667      1.000000
# question-mission5-agent0   0.666667      1.000000
# question-mission24-agent0  0.750000      1.000000
# question-mission37-agent0  0.750000      0.750000
# question-mission10-agent0  0.750000      1.000000
# question-mission63-agent8  1.000000      1.000000
# question-mission44-agent6  1.000000      0.333333
# question-mission8-agent0   1.000000      1.000000
# question-mission7-agent0   1.000000      1.000000
# question-mission35-agent0  1.000000      0.666667
# question-mission56-agent0  1.000000      1.000000
# question-mission31-agent6  1.000000      0.000000
# question-mission79-agent0  1.000000      1.000000
# question-mission42-agent7  1.000000      1.000000
# question-mission66-agent0  1.000000      1.000000

# %%
ax_questions_acc_all = df_questions_acc_all.plot.bar(figsize=(25,25))

# %%
fig_questions_acc_all = ax_questions_acc_all.get_figure()
fig_questions_acc_all.savefig('questions_acc_all.pdf')
